# %%
import sys, os
if 'google.colab' in sys.modules and not os.path.exists('.setup_complete'):
    # !wget -q https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/setup_colab.sh -O- | bash
    # !wget -q https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/week02_value_based/mdp.py
    # !touch .setup_complete

# This code creates a virtual display to draw game images on.
# It will have no effect if your machine has a monitor.
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY")) == 0:
    # !bash ../xvfb start
    os.environ['DISPLAY'] = ':1'
# Out:
# Starting virtual X frame buffer: Xvfb.

# %% [markdown]
# # HW Part 1: Value iteration convergence
#
# ### Find an MDP for which value iteration takes long to converge  (1 pts)
#
# When we ran value iteration on the small frozen lake problem, the last iteration where an action changed was iteration 6--i.e., value iteration computed the optimal policy at iteration 6. Are there any guarantees regarding how many iterations it'll take value iteration to compute the optimal policy? There are no such guarantees without additional assumptions--we can construct the MDP in such a way that the greedy policy will change after arbitrarily many iterations.
#
# Your task: define an MDP with at most 3 states and 2 actions, such that when you run value iteration, the optimal action changes at iteration >= 50. Use discount=0.95. (However, note that the discount doesn't matter here--you can construct an appropriate MDP with any discount.)
#
# Note: value function must change at least once after iteration >=50, not necessarily change on every iteration till >=50.

# %%
transition_probs = {
    's0': {
        'a0': {'s0': 1},
    },
    's1': {
        'a0': {'s2': 1},
        'a1': {'s0': 1}
    },
    's2': {
        'a0': {'s2': 1},
    }
}
rewards = {
    's1': {'a1': {'s0': 9.47}},
    's2': {'a0': {'s2': 1}},
}

from mdp import MDP
from mdp import FrozenLakeEnv
from numpy import random
import numpy as np
mdp = MDP(transition_probs, rewards, initial_state='s1')
# Feel free to change the initial_state

# %%
def get_action_value(mdp, state_values, state, action, gamma):
    """ Computes Q(s,a) as in formula above """

    q = 0
    for next_state, proba in mdp.get_next_states(state, action).items():
        q += proba * (mdp.get_reward(state, action, next_state) + gamma * state_values[next_state])

    return q
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def get_new_state_value(mdp, state_values, state, gamma):
    """ Computes next V(s) as in formula above. Please do not change state_values in process. """
    if mdp.is_terminal(state):
        return 0

    return max(get_action_value(mdp, state_values, state, action, gamma) for action in mdp.get_possible_actions(state))

# %%
def get_optimal_action(mdp, state_values, state, gamma=0.9):
    """ Finds optimal action using formula above. """
    if mdp.is_terminal(state):
        return None

    actions = mdp.get_possible_actions(state)
    indx = np.argmax([get_action_value(mdp, state_values, state, action, gamma) for action in actions])
    return actions[indx]

# %%
def value_iteration(mdp, state_values=None, gamma=0.9, num_iter=1000, min_difference=1e-5):
    """ performs num_iter value iteration steps starting from state_values. Same as before but in a function """
    state_values = state_values or {s: 0 for s in mdp.get_all_states()}
    for i in range(num_iter):

        # Compute new state values using the functions you defined above. It must be a dict {state : new_V(state)}
        new_state_values = {state : get_new_state_value(mdp, state_values, state, gamma) for state in mdp.get_all_states()}

        assert isinstance(new_state_values, dict)

        # Compute difference
        diff = max(abs(new_state_values[s] - state_values[s])
                   for s in mdp.get_all_states())

        print("iter %4i   |   diff: %6.5f   |   " % (i, diff), end="")
        print('   '.join("V(%s) = %.3f" % (s, v) for s, v in state_values.items()))

        state_values = new_state_values
        if diff < min_difference:
            break

    return state_values

# %%
gamma = 0.95
state_values = {s: 0 for s in mdp.get_all_states()}
policy = np.array([get_optimal_action(mdp, state_values, state, gamma)
                   for state in sorted(mdp.get_all_states())])

for i in range(100):
    print("after iteration %i" % i)
    state_values = value_iteration(mdp, state_values, num_iter=1)

    new_policy = np.array([get_optimal_action(mdp, state_values, state, gamma)
                           for state in sorted(mdp.get_all_states())])

    n_changes = (policy != new_policy).sum()
    print(policy)
    print("N actions changed = %i \n" % n_changes)
    policy = new_policy

# please ignore iter 0 at each step
# Out:
# after iteration 0
# iter    0   |   diff: 9.47000   |   V(s0) = 0.000   V(s1) = 0.000   V(s2) = 0.000
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 1
# iter    0   |   diff: 0.90000   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 1.000
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 2
# iter    0   |   diff: 0.81000   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 1.900
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 3
# iter    0   |   diff: 0.72900   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 2.710
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 4
# iter    0   |   diff: 0.65610   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 3.439
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 5
# iter    0   |   diff: 0.59049   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 4.095
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 6
# iter    0   |   diff: 0.53144   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 4.686
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 7
# iter    0   |   diff: 0.47830   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 5.217
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 8
# iter    0   |   diff: 0.43047   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 5.695
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 9
# iter    0   |   diff: 0.38742   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 6.126
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 10
# iter    0   |   diff: 0.34868   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 6.513
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 11
# iter    0   |   diff: 0.31381   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 6.862
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 12
# iter    0   |   diff: 0.28243   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 7.176
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 13
# iter    0   |   diff: 0.25419   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 7.458
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 14
# iter    0   |   diff: 0.22877   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 7.712
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 15
# iter    0   |   diff: 0.20589   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 7.941
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 16
# iter    0   |   diff: 0.18530   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 8.147
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 17
# iter    0   |   diff: 0.16677   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 8.332
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 18
# iter    0   |   diff: 0.15009   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 8.499
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 19
# iter    0   |   diff: 0.13509   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 8.649
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 20
# iter    0   |   diff: 0.12158   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 8.784
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 21
# iter    0   |   diff: 0.10942   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 8.906
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 22
# iter    0   |   diff: 0.09848   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.015
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 23
# iter    0   |   diff: 0.08863   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.114
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 24
# iter    0   |   diff: 0.07977   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.202
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 25
# iter    0   |   diff: 0.07179   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.282
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 26
# iter    0   |   diff: 0.06461   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.354
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 27
# iter    0   |   diff: 0.05815   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.419
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 28
# iter    0   |   diff: 0.05233   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.477
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 29
# iter    0   |   diff: 0.04710   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.529
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 30
# iter    0   |   diff: 0.04239   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.576
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 31
# iter    0   |   diff: 0.03815   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.618
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 32
# iter    0   |   diff: 0.03434   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.657
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 33
# iter    0   |   diff: 0.03090   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.691
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 34
# iter    0   |   diff: 0.02781   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.722
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 35
# iter    0   |   diff: 0.02503   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.750
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 36
# iter    0   |   diff: 0.02253   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.775
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 37
# iter    0   |   diff: 0.02028   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.797
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 38
# iter    0   |   diff: 0.01825   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.818
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 39
# iter    0   |   diff: 0.01642   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.836
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 40
# iter    0   |   diff: 0.01478   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.852
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 41
# iter    0   |   diff: 0.01330   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.867
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 42
# iter    0   |   diff: 0.01197   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.880
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 43
# iter    0   |   diff: 0.01078   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.892
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 44
# iter    0   |   diff: 0.00970   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.903
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 45
# iter    0   |   diff: 0.00873   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.913
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 46
# iter    0   |   diff: 0.00786   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.921
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 47
# iter    0   |   diff: 0.00707   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.929
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 48
# iter    0   |   diff: 0.00636   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.936
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 49
# iter    0   |   diff: 0.00573   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.943
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 50
# iter    0   |   diff: 0.00515   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.948
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 51
# iter    0   |   diff: 0.00464   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.954
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 52
# iter    0   |   diff: 0.00417   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.958
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 53
# iter    0   |   diff: 0.00376   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.962
# ['a0' 'a1' 'a0']
# N actions changed = 0
#
# after iteration 54
# iter    0   |   diff: 0.00338   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.966
# ['a0' 'a1' 'a0']
# N actions changed = 1
#
# after iteration 55
# iter    0   |   diff: 0.00304   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.970
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 56
# iter    0   |   diff: 0.00274   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.973
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 57
# iter    0   |   diff: 0.00247   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.975
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 58
# iter    0   |   diff: 0.00222   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.978
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 59
# iter    0   |   diff: 0.00200   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.980
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 60
# iter    0   |   diff: 0.00180   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.982
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 61
# iter    0   |   diff: 0.00162   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.984
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 62
# iter    0   |   diff: 0.00146   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.985
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 63
# iter    0   |   diff: 0.00131   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.987
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 64
# iter    0   |   diff: 0.00118   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.988
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 65
# iter    0   |   diff: 0.00106   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.989
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 66
# iter    0   |   diff: 0.00096   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.990
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 67
# iter    0   |   diff: 0.00086   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.991
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 68
# iter    0   |   diff: 0.00077   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.992
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 69
# iter    0   |   diff: 0.00070   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.993
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 70
# iter    0   |   diff: 0.00063   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.994
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 71
# iter    0   |   diff: 0.00056   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.994
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 72
# iter    0   |   diff: 0.00051   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.995
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 73
# iter    0   |   diff: 0.00046   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.995
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 74
# iter    0   |   diff: 0.00041   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.996
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 75
# iter    0   |   diff: 0.00037   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.996
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 76
# iter    0   |   diff: 0.00033   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.997
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 77
# iter    0   |   diff: 0.00030   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.997
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 78
# iter    0   |   diff: 0.00027   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.997
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 79
# iter    0   |   diff: 0.00024   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.998
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 80
# iter    0   |   diff: 0.00022   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.998
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 81
# iter    0   |   diff: 0.00020   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.998
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 82
# iter    0   |   diff: 0.00018   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.998
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 83
# iter    0   |   diff: 0.00016   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.998
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 84
# iter    0   |   diff: 0.00014   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.999
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 85
# iter    0   |   diff: 0.00013   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.999
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 86
# iter    0   |   diff: 0.00012   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.999
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 87
# iter    0   |   diff: 0.00010   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.999
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 88
# iter    0   |   diff: 0.00009   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.999
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 89
# iter    0   |   diff: 0.00008   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.999
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 90
# iter    0   |   diff: 0.00008   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.999
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 91
# iter    0   |   diff: 0.00007   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.999
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 92
# iter    0   |   diff: 0.00006   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.999
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 93
# iter    0   |   diff: 0.00006   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 9.999
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 94
# iter    0   |   diff: 0.00005   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 10.000
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 95
# iter    0   |   diff: 0.00004   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 10.000
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 96
# iter    0   |   diff: 0.00004   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 10.000
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 97
# iter    0   |   diff: 0.00004   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 10.000
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 98
# iter    0   |   diff: 0.00003   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 10.000
# ['a0' 'a0' 'a0']
# N actions changed = 0
#
# after iteration 99
# iter    0   |   diff: 0.00003   |   V(s0) = 0.000   V(s1) = 9.470   V(s2) = 10.000
# ['a0' 'a0' 'a0']
# N actions changed = 0

# %% [markdown]
# ### Value iteration convervence proof (1 pts)
# **Note:** Assume that $\mathcal{S}, \mathcal{A}$ are finite.
#
# Update of value function in value iteration can be rewritten in a form of Bellman operator:
#
# $$(TV)(s) = \max_{a \in \mathcal{A}}\mathbb{E}\left[ r_{t+1} + \gamma V(s_{t+1}) | s_t = s, a_t = a\right]$$
#
# Value iteration algorithm with Bellman operator:
#
# ---
# &nbsp;&nbsp; Initialize $V_0$
#
# &nbsp;&nbsp; **for** $k = 0,1,2,...$ **do**
#
# &nbsp;&nbsp;&nbsp;&nbsp; $V_{k+1} \leftarrow TV_k$
#
# &nbsp;&nbsp;**end for**
#
# ---
#
# In [lecture](https://docs.google.com/presentation/d/1lz2oIUTvd2MHWKEQSH8hquS66oe4MZ_eRvVViZs2uuE/edit#slide=id.g4fd6bae29e_2_4) we established contraction property of bellman operator:
#
# $$
# ||TV - TU||_{\infty} \le \gamma ||V - U||_{\infty}
# $$
#
# For all $V, U$
#
# Using contraction property of Bellman operator, Banach fixed-point theorem and Bellman equations prove that value function converges to $V^*$ in value iterateion
#
# Proof.
# $$
# \left\|V_k-V^*\right\|_{\infty}=\left\|T V_{k-1}-TV^*\right\|_{\infty} \leq \gamma\left\|V_{k-1}-V^*\right\|_{\infty} \leq \cdots \leq \gamma^k\left\|V_0-V^*\right\|_{\infty}
# $$
# При $k \rightarrow \infty$
# $$\left\|V_k-V^*\right\|_{\infty} \rightarrow 0$$
# Отсюда $$\lim _{k \rightarrow \infty} V_k=V^*$$

# %% [markdown]
# ### Asynchronious value iteration (2 pts)
#
# Consider the following algorithm:
#
# ---
#
# Initialize $V_0$
#
# **for** $k = 0,1,2,...$ **do**
#
# &nbsp;&nbsp;&nbsp;&nbsp; Select some state $s_k \in \mathcal{S}$
#
# &nbsp;&nbsp;&nbsp;&nbsp; $V(s_k) := (TV)(s_k)$
#
# **end for**
#
# ---
#
#
# Note that unlike common value iteration, here we update only a single state at a time.
#
# **Homework.** Prove the following proposition:
#
# If for all $s \in \mathcal{S}$, $s$ appears in the sequence $(s_0, s_1, ...)$ infinitely often, then $V$ converges to $V*$
#
# Proof.
#
# $\left\|V_{t+1}-V^*\right\|_{\infty} \leq \left\|V_{t+1}-V^*\right\|_1 = \sum_{i=1}^{|\mathcal{S}|} \left|V_{t+1}\left(s_i\right) - V^*\left(s_i\right)\right|$
# Выделим подпоследовательность $s_{k_n}$ состоящую из одинаковых состояний, $n\rightarrow\infty$ Для нее задача сводится к обычному value iteration c одним состоянием и $$\left|V_n(s)-V^*(s)\right| \rightarrow 0$$ $$\lim _{n \rightarrow \infty} V_n(s)=V^*(s)$$
#
# Тогда при $k \rightarrow \infty$
# $$\left\|V_{t+1}-V^*\right\|_{\infty} \leq \sum_{i=1}^{|\mathcal{S}|} \left|V_{t+1}\left(s_i\right) - V^*\left(s_i\right)\right| \rightarrow 0$$
#
# $$\lim _{k \rightarrow \infty} V_k=V^*$$

# %% [markdown]
# # HW Part 2: Policy iteration
#
# ## Policy iteration implementateion (3 pts)
#
# Let's implement exact policy iteration (PI), which has the following pseudocode:
#
# ---
# Initialize $\pi_0$   `// random or fixed action`
#
# For $n=0, 1, 2, \dots$
# - Compute the state-value function $V^{\pi_{n}}$
# - Using $V^{\pi_{n}}$, compute the state-action-value function $Q^{\pi_{n}}$
# - Compute new policy $\pi_{n+1}(s) = \operatorname*{argmax}_a Q^{\pi_{n}}(s,a)$
# ---
#
# Unlike VI, policy iteration has to maintain a policy - chosen actions from all states - and estimate $V^{\pi_{n}}$ based on this policy. It only changes policy once values converged.
#
#
# Below are a few helpers that you may or may not use in your implementation.

# %%
transition_probs = {
    's0': {
        'a0': {'s0': 0.5, 's2': 0.5},
        'a1': {'s2': 1}
    },
    's1': {
        'a0': {'s0': 0.7, 's1': 0.1, 's2': 0.2},
        'a1': {'s1': 0.95, 's2': 0.05}
    },
    's2': {
        'a0': {'s0': 0.4, 's1': 0.6},
        'a1': {'s0': 0.3, 's1': 0.3, 's2': 0.4}
    }
}
rewards = {
    's1': {'a0': {'s0': +5}},
    's2': {'a1': {'s0': -1}}
}

from mdp import MDP
mdp = MDP(transition_probs, rewards, initial_state='s0')

# %% [markdown]
# Let's write a function called `compute_vpi` that computes the state-value function $V^{\pi}$ for an arbitrary policy $\pi$.
#
# Unlike VI, this time you must find the exact solution, not just a single iteration.
#
# Recall that $V^{\pi}$ satisfies the following linear equation:
# $$V^{\pi}(s) = \sum_{s'} P(s,\pi(s),s')[ R(s,\pi(s),s') + \gamma V^{\pi}(s')]$$
#
# You'll have to solve a linear system in your code. (Find an exact solution, e.g., with `np.linalg.solve`.)

# %%
def compute_vpi(mdp, policy, gamma):
    """
    Computes V^pi(s) FOR ALL STATES under given policy.
    :param policy: a dict of currently chosen actions {s : a}
    :returns: a dict {state : V^pi(state) for all states}
    """
    state_to_idx = {s: i for i, s in enumerate(mdp.get_all_states())}
    n_states = len(mdp.get_all_states())

    A = np.zeros((n_states, n_states))
    B = np.zeros(n_states)

    for state in mdp.get_all_states():
        if policy[state] is not None:
            for next_state, proba in mdp.get_next_states(state, policy[state]).items():
                A[state_to_idx[state], state_to_idx[next_state]] -= proba * gamma
                B[state_to_idx[state]] += proba * mdp.get_reward(state, policy[state], next_state)

        A[state_to_idx[state], state_to_idx[state]] += 1

    value_states = np.linalg.solve(A, B)
    return {s : value_states[state_to_idx[s]] for s in mdp.get_all_states()}

# %%
test_policy = {s: np.random.choice(
    mdp.get_possible_actions(s)) for s in mdp.get_all_states()}
new_vpi = compute_vpi(mdp, test_policy, gamma)

print(new_vpi)

assert type(
    new_vpi) is dict, "compute_vpi must return a dict {state : V^pi(state) for all states}"
# Out:
# {'s0': -1.354537976418974, 's1': -0.6946348597020378, 's2': -1.425829448862078}

# %% [markdown]
# Once we've got new state values, it's time to update our policy.

# %%
def compute_new_policy(mdp, vpi, gamma):
    """
    Computes new policy as argmax of state values
    :param vpi: a dict {state : V^pi(state) for all states}
    :returns: a dict {state : optimal action for all states}
    """
    new_policy = {}

    for state in mdp.get_all_states():
        new_policy[state] = get_optimal_action(mdp, vpi, state, gamma)

    return new_policy

# %%
new_policy = compute_new_policy(mdp, new_vpi, gamma)

print(new_policy)

assert type(
    new_policy) is dict, "compute_new_policy must return a dict {state : optimal action for all states}"
# Out:
# {'s0': 'a0', 's1': 'a0', 's2': 'a0'}

# %% [markdown]
# __Main loop__

# %%
def policy_iteration(mdp, policy=None, gamma=0.9, num_iter=1000, min_difference=1e-5):
    """
    Run the policy iteration loop for num_iter iterations or till difference between V(s) is below min_difference.
    If policy is not given, initialize it at random.
    """
    state_values = {s: 0 for s in mdp.get_all_states()}
    policy = policy if policy is not None else compute_new_policy(mdp, state_values, gamma)

    for i in range(num_iter):
        new_state_values = compute_vpi(mdp, policy, gamma)
        new_policy = compute_new_policy(mdp, new_state_values, gamma)

        diff = max(abs(new_state_values[s] - state_values[s])
                   for s in mdp.get_all_states())

        print("iter %4i   |   diff: %6.5f   |   " % (i, diff), end="")
        print('   '.join("V(%s) = %.3f" % (s, v) for s, v in state_values.items()))

        state_values = new_state_values
        policy = new_policy
        if diff < min_difference:
            break

    return state_values, policy

# %% [markdown]
# __Your PI Results__

# %%
print("VI MDP")
s = mdp.reset()
state_values = value_iteration(mdp)
rewards = []
for _ in range(10000):
    s, r, done, _ = mdp.step(get_optimal_action(mdp, state_values, s, gamma))
    rewards.append(r)

print("average reward: ", np.mean(rewards))
# Out:
# VI MDP
# iter    0   |   diff: 3.50000   |   V(s0) = 0.000   V(s1) = 0.000   V(s2) = 0.000
# iter    1   |   diff: 1.89000   |   V(s0) = 0.000   V(s1) = 3.500   V(s2) = 0.000
# iter    2   |   diff: 1.70100   |   V(s0) = 0.000   V(s1) = 3.815   V(s2) = 1.890
# iter    3   |   diff: 1.13542   |   V(s0) = 1.701   V(s1) = 4.184   V(s2) = 2.060
# iter    4   |   diff: 0.73024   |   V(s0) = 1.854   V(s1) = 5.319   V(s2) = 2.871
# iter    5   |   diff: 0.61135   |   V(s0) = 2.584   V(s1) = 5.664   V(s2) = 3.540
# iter    6   |   diff: 0.54664   |   V(s0) = 3.186   V(s1) = 6.275   V(s2) = 3.989
# iter    7   |   diff: 0.49198   |   V(s0) = 3.590   V(s1) = 6.790   V(s2) = 4.535
# iter    8   |   diff: 0.42210   |   V(s0) = 4.082   V(s1) = 7.189   V(s2) = 4.959
# iter    9   |   diff: 0.36513   |   V(s0) = 4.463   V(s1) = 7.611   V(s2) = 5.352
# iter   10   |   diff: 0.32862   |   V(s0) = 4.816   V(s1) = 7.960   V(s2) = 5.717
# iter   11   |   diff: 0.29262   |   V(s0) = 5.145   V(s1) = 8.280   V(s2) = 6.032
# iter   12   |   diff: 0.26189   |   V(s0) = 5.429   V(s1) = 8.572   V(s2) = 6.323
# iter   13   |   diff: 0.23503   |   V(s0) = 5.691   V(s1) = 8.830   V(s2) = 6.584
# iter   14   |   diff: 0.21124   |   V(s0) = 5.925   V(s1) = 9.065   V(s2) = 6.817
# iter   15   |   diff: 0.19012   |   V(s0) = 6.135   V(s1) = 9.276   V(s2) = 7.028
# iter   16   |   diff: 0.17091   |   V(s0) = 6.325   V(s1) = 9.465   V(s2) = 7.218
# iter   17   |   diff: 0.15366   |   V(s0) = 6.496   V(s1) = 9.636   V(s2) = 7.388
# iter   18   |   diff: 0.13830   |   V(s0) = 6.649   V(s1) = 9.790   V(s2) = 7.542
# iter   19   |   diff: 0.12445   |   V(s0) = 6.788   V(s1) = 9.928   V(s2) = 7.680
# iter   20   |   diff: 0.11200   |   V(s0) = 6.912   V(s1) = 10.052   V(s2) = 7.805
# iter   21   |   diff: 0.10079   |   V(s0) = 7.024   V(s1) = 10.164   V(s2) = 7.917
# iter   22   |   diff: 0.09071   |   V(s0) = 7.125   V(s1) = 10.265   V(s2) = 8.017
# iter   23   |   diff: 0.08164   |   V(s0) = 7.216   V(s1) = 10.356   V(s2) = 8.108
# iter   24   |   diff: 0.07347   |   V(s0) = 7.297   V(s1) = 10.437   V(s2) = 8.190
# iter   25   |   diff: 0.06612   |   V(s0) = 7.371   V(s1) = 10.511   V(s2) = 8.263
# iter   26   |   diff: 0.05951   |   V(s0) = 7.437   V(s1) = 10.577   V(s2) = 8.329
# iter   27   |   diff: 0.05356   |   V(s0) = 7.496   V(s1) = 10.636   V(s2) = 8.389
# iter   28   |   diff: 0.04820   |   V(s0) = 7.550   V(s1) = 10.690   V(s2) = 8.442
# iter   29   |   diff: 0.04338   |   V(s0) = 7.598   V(s1) = 10.738   V(s2) = 8.491
# iter   30   |   diff: 0.03904   |   V(s0) = 7.641   V(s1) = 10.782   V(s2) = 8.534
# iter   31   |   diff: 0.03514   |   V(s0) = 7.681   V(s1) = 10.821   V(s2) = 8.573
# iter   32   |   diff: 0.03163   |   V(s0) = 7.716   V(s1) = 10.856   V(s2) = 8.608
# iter   33   |   diff: 0.02846   |   V(s0) = 7.747   V(s1) = 10.887   V(s2) = 8.640
# iter   34   |   diff: 0.02562   |   V(s0) = 7.776   V(s1) = 10.916   V(s2) = 8.668
# iter   35   |   diff: 0.02306   |   V(s0) = 7.801   V(s1) = 10.941   V(s2) = 8.694
# iter   36   |   diff: 0.02075   |   V(s0) = 7.824   V(s1) = 10.964   V(s2) = 8.717
# iter   37   |   diff: 0.01867   |   V(s0) = 7.845   V(s1) = 10.985   V(s2) = 8.738
# iter   38   |   diff: 0.01681   |   V(s0) = 7.864   V(s1) = 11.004   V(s2) = 8.756
# iter   39   |   diff: 0.01513   |   V(s0) = 7.881   V(s1) = 11.021   V(s2) = 8.773
# iter   40   |   diff: 0.01361   |   V(s0) = 7.896   V(s1) = 11.036   V(s2) = 8.788
# iter   41   |   diff: 0.01225   |   V(s0) = 7.909   V(s1) = 11.049   V(s2) = 8.802
# iter   42   |   diff: 0.01103   |   V(s0) = 7.922   V(s1) = 11.062   V(s2) = 8.814
# iter   43   |   diff: 0.00992   |   V(s0) = 7.933   V(s1) = 11.073   V(s2) = 8.825
# iter   44   |   diff: 0.00893   |   V(s0) = 7.943   V(s1) = 11.083   V(s2) = 8.835
# iter   45   |   diff: 0.00804   |   V(s0) = 7.952   V(s1) = 11.092   V(s2) = 8.844
# iter   46   |   diff: 0.00724   |   V(s0) = 7.960   V(s1) = 11.100   V(s2) = 8.852
# iter   47   |   diff: 0.00651   |   V(s0) = 7.967   V(s1) = 11.107   V(s2) = 8.859
# iter   48   |   diff: 0.00586   |   V(s0) = 7.973   V(s1) = 11.113   V(s2) = 8.866
# iter   49   |   diff: 0.00527   |   V(s0) = 7.979   V(s1) = 11.119   V(s2) = 8.872
# iter   50   |   diff: 0.00475   |   V(s0) = 7.984   V(s1) = 11.125   V(s2) = 8.877
# iter   51   |   diff: 0.00427   |   V(s0) = 7.989   V(s1) = 11.129   V(s2) = 8.882
# iter   52   |   diff: 0.00384   |   V(s0) = 7.993   V(s1) = 11.134   V(s2) = 8.886
# iter   53   |   diff: 0.00346   |   V(s0) = 7.997   V(s1) = 11.137   V(s2) = 8.890
# iter   54   |   diff: 0.00311   |   V(s0) = 8.001   V(s1) = 11.141   V(s2) = 8.893
# iter   55   |   diff: 0.00280   |   V(s0) = 8.004   V(s1) = 11.144   V(s2) = 8.896
# iter   56   |   diff: 0.00252   |   V(s0) = 8.007   V(s1) = 11.147   V(s2) = 8.899
# iter   57   |   diff: 0.00227   |   V(s0) = 8.009   V(s1) = 11.149   V(s2) = 8.902
# iter   58   |   diff: 0.00204   |   V(s0) = 8.011   V(s1) = 11.152   V(s2) = 8.904
# iter   59   |   diff: 0.00184   |   V(s0) = 8.014   V(s1) = 11.154   V(s2) = 8.906
# iter   60   |   diff: 0.00166   |   V(s0) = 8.015   V(s1) = 11.155   V(s2) = 8.908
# iter   61   |   diff: 0.00149   |   V(s0) = 8.017   V(s1) = 11.157   V(s2) = 8.909
# iter   62   |   diff: 0.00134   |   V(s0) = 8.019   V(s1) = 11.159   V(s2) = 8.911
# iter   63   |   diff: 0.00121   |   V(s0) = 8.020   V(s1) = 11.160   V(s2) = 8.912
# iter   64   |   diff: 0.00109   |   V(s0) = 8.021   V(s1) = 11.161   V(s2) = 8.913
# iter   65   |   diff: 0.00098   |   V(s0) = 8.022   V(s1) = 11.162   V(s2) = 8.915
# iter   66   |   diff: 0.00088   |   V(s0) = 8.023   V(s1) = 11.163   V(s2) = 8.916
# iter   67   |   diff: 0.00079   |   V(s0) = 8.024   V(s1) = 11.164   V(s2) = 8.916
# iter   68   |   diff: 0.00071   |   V(s0) = 8.025   V(s1) = 11.165   V(s2) = 8.917
# iter   69   |   diff: 0.00064   |   V(s0) = 8.026   V(s1) = 11.166   V(s2) = 8.918
# iter   70   |   diff: 0.00058   |   V(s0) = 8.026   V(s1) = 11.166   V(s2) = 8.919
# iter   71   |   diff: 0.00052   |   V(s0) = 8.027   V(s1) = 11.167   V(s2) = 8.919
# iter   72   |   diff: 0.00047   |   V(s0) = 8.027   V(s1) = 11.167   V(s2) = 8.920
# iter   73   |   diff: 0.00042   |   V(s0) = 8.028   V(s1) = 11.168   V(s2) = 8.920
# iter   74   |   diff: 0.00038   |   V(s0) = 8.028   V(s1) = 11.168   V(s2) = 8.921
# iter   75   |   diff: 0.00034   |   V(s0) = 8.029   V(s1) = 11.169   V(s2) = 8.921
# iter   76   |   diff: 0.00031   |   V(s0) = 8.029   V(s1) = 11.169   V(s2) = 8.921
# iter   77   |   diff: 0.00028   |   V(s0) = 8.029   V(s1) = 11.169   V(s2) = 8.922
# iter   78   |   diff: 0.00025   |   V(s0) = 8.029   V(s1) = 11.169   V(s2) = 8.922
# iter   79   |   diff: 0.00022   |   V(s0) = 8.030   V(s1) = 11.170   V(s2) = 8.922
# iter   80   |   diff: 0.00020   |   V(s0) = 8.030   V(s1) = 11.170   V(s2) = 8.922
# iter   81   |   diff: 0.00018   |   V(s0) = 8.030   V(s1) = 11.170   V(s2) = 8.923
# iter   82   |   diff: 0.00016   |   V(s0) = 8.030   V(s1) = 11.170   V(s2) = 8.923
# iter   83   |   diff: 0.00015   |   V(s0) = 8.030   V(s1) = 11.171   V(s2) = 8.923
# iter   84   |   diff: 0.00013   |   V(s0) = 8.031   V(s1) = 11.171   V(s2) = 8.923
# iter   85   |   diff: 0.00012   |   V(s0) = 8.031   V(s1) = 11.171   V(s2) = 8.923
# iter   86   |   diff: 0.00011   |   V(s0) = 8.031   V(s1) = 11.171   V(s2) = 8.923
# iter   87   |   diff: 0.00010   |   V(s0) = 8.031   V(s1) = 11.171   V(s2) = 8.923
# iter   88   |   diff: 0.00009   |   V(s0) = 8.031   V(s1) = 11.171   V(s2) = 8.923
# iter   89   |   diff: 0.00008   |   V(s0) = 8.031   V(s1) = 11.171   V(s2) = 8.924
# iter   90   |   diff: 0.00007   |   V(s0) = 8.031   V(s1) = 11.171   V(s2) = 8.924
# iter   91   |   diff: 0.00006   |   V(s0) = 8.031   V(s1) = 11.171   V(s2) = 8.924
# iter   92   |   diff: 0.00006   |   V(s0) = 8.031   V(s1) = 11.171   V(s2) = 8.924
# iter   93   |   diff: 0.00005   |   V(s0) = 8.031   V(s1) = 11.171   V(s2) = 8.924
# iter   94   |   diff: 0.00005   |   V(s0) = 8.031   V(s1) = 11.172   V(s2) = 8.924
# iter   95   |   diff: 0.00004   |   V(s0) = 8.032   V(s1) = 11.172   V(s2) = 8.924
# iter   96   |   diff: 0.00004   |   V(s0) = 8.032   V(s1) = 11.172   V(s2) = 8.924
# iter   97   |   diff: 0.00003   |   V(s0) = 8.032   V(s1) = 11.172   V(s2) = 8.924
# iter   98   |   diff: 0.00003   |   V(s0) = 8.032   V(s1) = 11.172   V(s2) = 8.924
# iter   99   |   diff: 0.00003   |   V(s0) = 8.032   V(s1) = 11.172   V(s2) = 8.924
# iter  100   |   diff: 0.00002   |   V(s0) = 8.032   V(s1) = 11.172   V(s2) = 8.924
# iter  101   |   diff: 0.00002   |   V(s0) = 8.032   V(s1) = 11.172   V(s2) = 8.924
# iter  102   |   diff: 0.00002   |   V(s0) = 8.032   V(s1) = 11.172   V(s2) = 8.924
# iter  103   |   diff: 0.00002   |   V(s0) = 8.032   V(s1) = 11.172   V(s2) = 8.924
# iter  104   |   diff: 0.00002   |   V(s0) = 8.032   V(s1) = 11.172   V(s2) = 8.924
# iter  105   |   diff: 0.00001   |   V(s0) = 8.032   V(s1) = 11.172   V(s2) = 8.924
# iter  106   |   diff: 0.00001   |   V(s0) = 8.032   V(s1) = 11.172   V(s2) = 8.924
# iter  107   |   diff: 0.00001   |   V(s0) = 8.032   V(s1) = 11.172   V(s2) = 8.924
# iter  108   |   diff: 0.00001   |   V(s0) = 8.032   V(s1) = 11.172   V(s2) = 8.924
# iter  109   |   diff: 0.00001   |   V(s0) = 8.032   V(s1) = 11.172   V(s2) = 8.924
# average reward:  0.936

# %%
print("PI MDP")
s = mdp.reset()
state_values, policy = policy_iteration(mdp)
rewards = []
for _ in range(10000):
    s, r, done, _ = mdp.step(policy[s])
    rewards.append(r)

print("average reward: ", np.mean(rewards))
# Out:
# PI MDP
# iter    0   |   diff: 9.26773   |   V(s0) = 0.000   V(s1) = 0.000   V(s2) = 0.000
# iter    1   |   diff: 2.22765   |   V(s0) = 5.804   V(s1) = 9.268   V(s2) = 7.094
# iter    2   |   diff: 0.00000   |   V(s0) = 8.032   V(s1) = 11.172   V(s2) = 8.924
# average reward:  0.934

# %%
from mdp import FrozenLakeEnv
mdp = FrozenLakeEnv(slip_chance=0)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print("VI small FrozenLake")
s = mdp.reset()
state_values= value_iteration(mdp)
mdp.render()
for t in range(100):
    a = get_optimal_action(mdp, state_values, s, gamma)
    print(a, end='\n\n')
    s, r, done, _ = mdp.step(a)
    mdp.render()
    if done:
        break
# Out:
# VI small FrozenLake
# iter    0   |   diff: 1.00000   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 0.000   V((3, 3)) = 0.000
# iter    1   |   diff: 0.90000   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 1.000   V((3, 3)) = 0.000
# iter    2   |   diff: 0.81000   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.900   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.900   V((3, 2)) = 1.000   V((3, 3)) = 0.000
# iter    3   |   diff: 0.72900   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.810   V((1, 3)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.810   V((2, 2)) = 0.900   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.900   V((3, 2)) = 1.000   V((3, 3)) = 0.000
# iter    4   |   diff: 0.65610   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.729   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.810   V((1, 3)) = 0.000   V((2, 0)) = 0.729   V((2, 1)) = 0.810   V((2, 2)) = 0.900   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.900   V((3, 2)) = 1.000   V((3, 3)) = 0.000
# iter    5   |   diff: 0.59049   |   V((0, 0)) = 0.000   V((0, 1)) = 0.656   V((0, 2)) = 0.729   V((0, 3)) = 0.656   V((1, 0)) = 0.656   V((1, 1)) = 0.000   V((1, 2)) = 0.810   V((1, 3)) = 0.000   V((2, 0)) = 0.729   V((2, 1)) = 0.810   V((2, 2)) = 0.900   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.900   V((3, 2)) = 1.000   V((3, 3)) = 0.000
# iter    6   |   diff: 0.00000   |   V((0, 0)) = 0.590   V((0, 1)) = 0.656   V((0, 2)) = 0.729   V((0, 3)) = 0.656   V((1, 0)) = 0.656   V((1, 1)) = 0.000   V((1, 2)) = 0.810   V((1, 3)) = 0.000   V((2, 0)) = 0.729   V((2, 1)) = 0.810   V((2, 2)) = 0.900   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.900   V((3, 2)) = 1.000   V((3, 3)) = 0.000
# *FFF
# FHFH
# FFFH
# HFFG
#
# down
#
# SFFF
# *HFH
# FFFH
# HFFG
#
# down
#
# SFFF
# FHFH
# *FFH
# HFFG
#
# right
#
# SFFF
# FHFH
# F*FH
# HFFG
#
# down
#
# SFFF
# FHFH
# FFFH
# H*FG
#
# right
#
# SFFF
# FHFH
# FFFH
# HF*G
#
# right
#
# SFFF
# FHFH
# FFFH
# HFF*

# %%
print("PI small FrozenLake")
s = mdp.reset()
state_values, policy = policy_iteration(mdp)
mdp.render()
for t in range(100):
    print(policy[s], end='\n\n')
    s, r, done, _ = mdp.step(policy[s])
    mdp.render()
    if done:
        break
# Out:
# PI small FrozenLake
# iter    0   |   diff: 1.00000   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 0.000   V((3, 3)) = 0.000
# iter    1   |   diff: 0.90000   |   V((0, 0)) = -0.000   V((0, 1)) = -0.000   V((0, 2)) = -0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((2, 0)) = -0.000   V((2, 1)) = -0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 1.000   V((3, 3)) = 0.000
# iter    2   |   diff: 0.81000   |   V((0, 0)) = -0.000   V((0, 1)) = -0.000   V((0, 2)) = -0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((2, 0)) = -0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.900   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.900   V((3, 2)) = 1.000   V((3, 3)) = 0.000
# iter    3   |   diff: 0.72900   |   V((0, 0)) = -0.000   V((0, 1)) = -0.000   V((0, 2)) = -0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.810   V((1, 3)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.810   V((2, 2)) = 0.900   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.900   V((3, 2)) = 1.000   V((3, 3)) = 0.000
# iter    4   |   diff: 0.65610   |   V((0, 0)) = -0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.729   V((0, 3)) = 0.656   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.810   V((1, 3)) = 0.000   V((2, 0)) = 0.729   V((2, 1)) = 0.810   V((2, 2)) = 0.900   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.900   V((3, 2)) = 1.000   V((3, 3)) = 0.000
# iter    5   |   diff: 0.59049   |   V((0, 0)) = 0.000   V((0, 1)) = 0.656   V((0, 2)) = 0.729   V((0, 3)) = 0.656   V((1, 0)) = 0.656   V((1, 1)) = 0.000   V((1, 2)) = 0.810   V((1, 3)) = 0.000   V((2, 0)) = 0.729   V((2, 1)) = 0.810   V((2, 2)) = 0.900   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.900   V((3, 2)) = 1.000   V((3, 3)) = 0.000
# iter    6   |   diff: 0.00000   |   V((0, 0)) = 0.590   V((0, 1)) = 0.656   V((0, 2)) = 0.729   V((0, 3)) = 0.656   V((1, 0)) = 0.656   V((1, 1)) = 0.000   V((1, 2)) = 0.810   V((1, 3)) = 0.000   V((2, 0)) = 0.729   V((2, 1)) = 0.810   V((2, 2)) = 0.900   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.900   V((3, 2)) = 1.000   V((3, 3)) = 0.000
# *FFF
# FHFH
# FFFH
# HFFG
#
# down
#
# SFFF
# *HFH
# FFFH
# HFFG
#
# down
#
# SFFF
# FHFH
# *FFH
# HFFG
#
# right
#
# SFFF
# FHFH
# F*FH
# HFFG
#
# down
#
# SFFF
# FHFH
# FFFH
# H*FG
#
# right
#
# SFFF
# FHFH
# FFFH
# HF*G
#
# right
#
# SFFF
# FHFH
# FFFH
# HFF*

# %%
mdp = FrozenLakeEnv(slip_chance=0)
state_values = value_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    rewards = []
    for t in range(100):
        s, r, done, _ = mdp.step(
            get_optimal_action(mdp, state_values, s, gamma))
        rewards.append(r)
        if done:
            break
    total_rewards.append(np.sum(rewards))

print("average reward: ", np.mean(total_rewards))
assert(1.0 <= np.mean(total_rewards) <= 1.0)
print("Well done!")
# Out:
# iter    0   |   diff: 1.00000   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 0.000   V((3, 3)) = 0.000
# iter    1   |   diff: 0.90000   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 1.000   V((3, 3)) = 0.000
# iter    2   |   diff: 0.81000   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.900   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.900   V((3, 2)) = 1.000   V((3, 3)) = 0.000
# iter    3   |   diff: 0.72900   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.810   V((1, 3)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.810   V((2, 2)) = 0.900   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.900   V((3, 2)) = 1.000   V((3, 3)) = 0.000
# iter    4   |   diff: 0.65610   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.729   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.810   V((1, 3)) = 0.000   V((2, 0)) = 0.729   V((2, 1)) = 0.810   V((2, 2)) = 0.900   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.900   V((3, 2)) = 1.000   V((3, 3)) = 0.000
# iter    5   |   diff: 0.59049   |   V((0, 0)) = 0.000   V((0, 1)) = 0.656   V((0, 2)) = 0.729   V((0, 3)) = 0.656   V((1, 0)) = 0.656   V((1, 1)) = 0.000   V((1, 2)) = 0.810   V((1, 3)) = 0.000   V((2, 0)) = 0.729   V((2, 1)) = 0.810   V((2, 2)) = 0.900   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.900   V((3, 2)) = 1.000   V((3, 3)) = 0.000
# iter    6   |   diff: 0.00000   |   V((0, 0)) = 0.590   V((0, 1)) = 0.656   V((0, 2)) = 0.729   V((0, 3)) = 0.656   V((1, 0)) = 0.656   V((1, 1)) = 0.000   V((1, 2)) = 0.810   V((1, 3)) = 0.000   V((2, 0)) = 0.729   V((2, 1)) = 0.810   V((2, 2)) = 0.900   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.900   V((3, 2)) = 1.000   V((3, 3)) = 0.000
# average reward:  1.0
# Well done!

# %%
mdp = FrozenLakeEnv(slip_chance=0)
state_values, policy = policy_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    rewards = []
    for t in range(100):
        s, r, done, _ = mdp.step(policy[s])
        rewards.append(r)
        if done:
            break
    total_rewards.append(np.sum(rewards))

print("average reward: ", np.mean(total_rewards))
assert(1.0 <= np.mean(total_rewards) <= 1.0)
print("Well done!")
# Out:
# iter    0   |   diff: 1.00000   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 0.000   V((3, 3)) = 0.000
# iter    1   |   diff: 0.90000   |   V((0, 0)) = -0.000   V((0, 1)) = -0.000   V((0, 2)) = -0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((2, 0)) = -0.000   V((2, 1)) = -0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 1.000   V((3, 3)) = 0.000
# iter    2   |   diff: 0.81000   |   V((0, 0)) = -0.000   V((0, 1)) = -0.000   V((0, 2)) = -0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((2, 0)) = -0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.900   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.900   V((3, 2)) = 1.000   V((3, 3)) = 0.000
# iter    3   |   diff: 0.72900   |   V((0, 0)) = -0.000   V((0, 1)) = -0.000   V((0, 2)) = -0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.810   V((1, 3)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.810   V((2, 2)) = 0.900   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.900   V((3, 2)) = 1.000   V((3, 3)) = 0.000
# iter    4   |   diff: 0.65610   |   V((0, 0)) = -0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.729   V((0, 3)) = 0.656   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.810   V((1, 3)) = 0.000   V((2, 0)) = 0.729   V((2, 1)) = 0.810   V((2, 2)) = 0.900   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.900   V((3, 2)) = 1.000   V((3, 3)) = 0.000
# iter    5   |   diff: 0.59049   |   V((0, 0)) = 0.000   V((0, 1)) = 0.656   V((0, 2)) = 0.729   V((0, 3)) = 0.656   V((1, 0)) = 0.656   V((1, 1)) = 0.000   V((1, 2)) = 0.810   V((1, 3)) = 0.000   V((2, 0)) = 0.729   V((2, 1)) = 0.810   V((2, 2)) = 0.900   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.900   V((3, 2)) = 1.000   V((3, 3)) = 0.000
# iter    6   |   diff: 0.00000   |   V((0, 0)) = 0.590   V((0, 1)) = 0.656   V((0, 2)) = 0.729   V((0, 3)) = 0.656   V((1, 0)) = 0.656   V((1, 1)) = 0.000   V((1, 2)) = 0.810   V((1, 3)) = 0.000   V((2, 0)) = 0.729   V((2, 1)) = 0.810   V((2, 2)) = 0.900   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.900   V((3, 2)) = 1.000   V((3, 3)) = 0.000
# average reward:  1.0
# Well done!

# %%
mdp = FrozenLakeEnv(slip_chance=0.1)
state_values = value_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    rewards = []
    for t in range(100):
        s, r, done, _ = mdp.step(
            get_optimal_action(mdp, state_values, s, gamma))
        rewards.append(r)
        if done:
            break
    total_rewards.append(np.sum(rewards))

print("average reward: ", np.mean(total_rewards))
assert(0.8 <= np.mean(total_rewards) <= 0.95)
print("Well done!")
# Out:
# iter    0   |   diff: 0.90000   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 0.000   V((3, 3)) = 0.000
# iter    1   |   diff: 0.72900   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 0.900   V((3, 3)) = 0.000
# iter    2   |   diff: 0.62330   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.729   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.729   V((3, 2)) = 0.941   V((3, 3)) = 0.000
# iter    3   |   diff: 0.50487   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.590   V((1, 3)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.623   V((2, 2)) = 0.762   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.795   V((3, 2)) = 0.975   V((3, 3)) = 0.000
# iter    4   |   diff: 0.40894   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.478   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.617   V((1, 3)) = 0.000   V((2, 0)) = 0.505   V((2, 1)) = 0.678   V((2, 2)) = 0.818   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.854   V((3, 2)) = 0.978   V((3, 3)) = 0.000
# iter    5   |   diff: 0.34868   |   V((0, 0)) = 0.000   V((0, 1)) = 0.387   V((0, 2)) = 0.500   V((0, 3)) = 0.387   V((1, 0)) = 0.409   V((1, 1)) = 0.000   V((1, 2)) = 0.663   V((1, 3)) = 0.000   V((2, 0)) = 0.549   V((2, 1)) = 0.751   V((2, 2)) = 0.823   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.861   V((3, 2)) = 0.981   V((3, 3)) = 0.000
# iter    6   |   diff: 0.06529   |   V((0, 0)) = 0.349   V((0, 1)) = 0.422   V((0, 2)) = 0.571   V((0, 3)) = 0.422   V((1, 0)) = 0.463   V((1, 1)) = 0.000   V((1, 2)) = 0.666   V((1, 3)) = 0.000   V((2, 0)) = 0.627   V((2, 1)) = 0.759   V((2, 2)) = 0.828   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.867   V((3, 2)) = 0.981   V((3, 3)) = 0.000
# iter    7   |   diff: 0.05832   |   V((0, 0)) = 0.410   V((0, 1)) = 0.482   V((0, 2)) = 0.578   V((0, 3)) = 0.482   V((1, 0)) = 0.528   V((1, 1)) = 0.000   V((1, 2)) = 0.671   V((1, 3)) = 0.000   V((2, 0)) = 0.636   V((2, 1)) = 0.768   V((2, 2)) = 0.829   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.868   V((3, 2)) = 0.981   V((3, 3)) = 0.000
# iter    8   |   diff: 0.01139   |   V((0, 0)) = 0.468   V((0, 1)) = 0.490   V((0, 2)) = 0.587   V((0, 3)) = 0.490   V((1, 0)) = 0.539   V((1, 1)) = 0.000   V((1, 2)) = 0.671   V((1, 3)) = 0.000   V((2, 0)) = 0.646   V((2, 1)) = 0.769   V((2, 2)) = 0.830   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.869   V((3, 2)) = 0.981   V((3, 3)) = 0.000
# iter    9   |   diff: 0.00764   |   V((0, 0)) = 0.480   V((0, 1)) = 0.497   V((0, 2)) = 0.588   V((0, 3)) = 0.497   V((1, 0)) = 0.547   V((1, 1)) = 0.000   V((1, 2)) = 0.672   V((1, 3)) = 0.000   V((2, 0)) = 0.647   V((2, 1)) = 0.770   V((2, 2)) = 0.830   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.869   V((3, 2)) = 0.981   V((3, 3)) = 0.000
# iter   10   |   diff: 0.00164   |   V((0, 0)) = 0.487   V((0, 1)) = 0.499   V((0, 2)) = 0.589   V((0, 3)) = 0.499   V((1, 0)) = 0.549   V((1, 1)) = 0.000   V((1, 2)) = 0.672   V((1, 3)) = 0.000   V((2, 0)) = 0.648   V((2, 1)) = 0.770   V((2, 2)) = 0.830   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.869   V((3, 2)) = 0.981   V((3, 3)) = 0.000
# iter   11   |   diff: 0.00094   |   V((0, 0)) = 0.489   V((0, 1)) = 0.500   V((0, 2)) = 0.589   V((0, 3)) = 0.500   V((1, 0)) = 0.550   V((1, 1)) = 0.000   V((1, 2)) = 0.672   V((1, 3)) = 0.000   V((2, 0)) = 0.648   V((2, 1)) = 0.770   V((2, 2)) = 0.830   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.869   V((3, 2)) = 0.982   V((3, 3)) = 0.000
# iter   12   |   diff: 0.00022   |   V((0, 0)) = 0.490   V((0, 1)) = 0.500   V((0, 2)) = 0.589   V((0, 3)) = 0.500   V((1, 0)) = 0.550   V((1, 1)) = 0.000   V((1, 2)) = 0.672   V((1, 3)) = 0.000   V((2, 0)) = 0.649   V((2, 1)) = 0.770   V((2, 2)) = 0.830   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.869   V((3, 2)) = 0.982   V((3, 3)) = 0.000
# iter   13   |   diff: 0.00011   |   V((0, 0)) = 0.490   V((0, 1)) = 0.500   V((0, 2)) = 0.589   V((0, 3)) = 0.500   V((1, 0)) = 0.550   V((1, 1)) = 0.000   V((1, 2)) = 0.672   V((1, 3)) = 0.000   V((2, 0)) = 0.649   V((2, 1)) = 0.770   V((2, 2)) = 0.830   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.869   V((3, 2)) = 0.982   V((3, 3)) = 0.000
# iter   14   |   diff: 0.00003   |   V((0, 0)) = 0.490   V((0, 1)) = 0.500   V((0, 2)) = 0.589   V((0, 3)) = 0.500   V((1, 0)) = 0.550   V((1, 1)) = 0.000   V((1, 2)) = 0.672   V((1, 3)) = 0.000   V((2, 0)) = 0.649   V((2, 1)) = 0.770   V((2, 2)) = 0.830   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.869   V((3, 2)) = 0.982   V((3, 3)) = 0.000
# iter   15   |   diff: 0.00001   |   V((0, 0)) = 0.490   V((0, 1)) = 0.500   V((0, 2)) = 0.589   V((0, 3)) = 0.500   V((1, 0)) = 0.550   V((1, 1)) = 0.000   V((1, 2)) = 0.672   V((1, 3)) = 0.000   V((2, 0)) = 0.649   V((2, 1)) = 0.770   V((2, 2)) = 0.830   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.869   V((3, 2)) = 0.982   V((3, 3)) = 0.000
# iter   16   |   diff: 0.00000   |   V((0, 0)) = 0.490   V((0, 1)) = 0.500   V((0, 2)) = 0.589   V((0, 3)) = 0.500   V((1, 0)) = 0.550   V((1, 1)) = 0.000   V((1, 2)) = 0.672   V((1, 3)) = 0.000   V((2, 0)) = 0.649   V((2, 1)) = 0.770   V((2, 2)) = 0.830   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.869   V((3, 2)) = 0.982   V((3, 3)) = 0.000
# average reward:  0.883
# Well done!

# %%
mdp = FrozenLakeEnv(slip_chance=0.1)
state_values, policy = policy_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    rewards = []
    for t in range(100):
        s, r, done, _ = mdp.step(policy[s])
        rewards.append(r)
        if done:
            break
    total_rewards.append(np.sum(rewards))

print("average reward: ", np.mean(total_rewards))
assert(0.8 <= np.mean(total_rewards) <= 0.95)
print("Well done!")
# Out:
# iter    0   |   diff: 0.94442   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 0.000   V((3, 3)) = 0.000
# iter    1   |   diff: 0.86576   |   V((0, 0)) = -0.000   V((0, 1)) = -0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((1, 0)) = -0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.002   V((1, 3)) = 0.000   V((2, 0)) = -0.000   V((2, 1)) = -0.000   V((2, 2)) = 0.043   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 0.944   V((3, 3)) = 0.000
# iter    2   |   diff: 0.60704   |   V((0, 0)) = 0.155   V((0, 1)) = 0.498   V((0, 2)) = 0.587   V((0, 3)) = 0.498   V((1, 0)) = 0.008   V((1, 1)) = 0.000   V((1, 2)) = 0.670   V((1, 3)) = 0.000   V((2, 0)) = 0.033   V((2, 1)) = 0.709   V((2, 2)) = 0.827   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.866   V((3, 2)) = 0.981   V((3, 3)) = 0.000
# iter    3   |   diff: 0.17560   |   V((0, 0)) = 0.442   V((0, 1)) = 0.500   V((0, 2)) = 0.589   V((0, 3)) = 0.500   V((1, 0)) = 0.375   V((1, 1)) = 0.000   V((1, 2)) = 0.672   V((1, 3)) = 0.000   V((2, 0)) = 0.640   V((2, 1)) = 0.770   V((2, 2)) = 0.830   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.869   V((3, 2)) = 0.982   V((3, 3)) = 0.000
# iter    4   |   diff: 0.04029   |   V((0, 0)) = 0.450   V((0, 1)) = 0.500   V((0, 2)) = 0.589   V((0, 3)) = 0.500   V((1, 0)) = 0.550   V((1, 1)) = 0.000   V((1, 2)) = 0.672   V((1, 3)) = 0.000   V((2, 0)) = 0.649   V((2, 1)) = 0.770   V((2, 2)) = 0.830   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.869   V((3, 2)) = 0.982   V((3, 3)) = 0.000
# iter    5   |   diff: 0.00000   |   V((0, 0)) = 0.490   V((0, 1)) = 0.500   V((0, 2)) = 0.589   V((0, 3)) = 0.500   V((1, 0)) = 0.550   V((1, 1)) = 0.000   V((1, 2)) = 0.672   V((1, 3)) = 0.000   V((2, 0)) = 0.649   V((2, 1)) = 0.770   V((2, 2)) = 0.830   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.869   V((3, 2)) = 0.982   V((3, 3)) = 0.000
# average reward:  0.881
# Well done!

# %%
mdp = FrozenLakeEnv(slip_chance=0.25)
state_values = value_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    rewards = []
    for t in range(100):
        s, r, done, _ = mdp.step(
            get_optimal_action(mdp, state_values, s, gamma))
        rewards.append(r)
        if done:
            break
    total_rewards.append(np.sum(rewards))

print("average reward: ", np.mean(total_rewards))
assert(0.6 <= np.mean(total_rewards) <= 0.7)
print("Well done!")
# Out:
# iter    0   |   diff: 0.75000   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 0.000   V((3, 3)) = 0.000
# iter    1   |   diff: 0.50625   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 0.750   V((3, 3)) = 0.000
# iter    2   |   diff: 0.39867   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.506   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.506   V((3, 2)) = 0.834   V((3, 3)) = 0.000
# iter    3   |   diff: 0.26910   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.342   V((1, 3)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.399   V((2, 2)) = 0.563   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.620   V((3, 2)) = 0.901   V((3, 3)) = 0.000
# iter    4   |   diff: 0.18164   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.231   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.380   V((1, 3)) = 0.000   V((2, 0)) = 0.269   V((2, 1)) = 0.482   V((2, 2)) = 0.653   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.723   V((3, 2)) = 0.915   V((3, 3)) = 0.000
# iter    5   |   diff: 0.14013   |   V((0, 0)) = 0.000   V((0, 1)) = 0.156   V((0, 2)) = 0.257   V((0, 3)) = 0.156   V((1, 0)) = 0.182   V((1, 1)) = 0.000   V((1, 2)) = 0.441   V((1, 3)) = 0.000   V((2, 0)) = 0.325   V((2, 1)) = 0.592   V((2, 2)) = 0.672   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.753   V((3, 2)) = 0.926   V((3, 3)) = 0.000
# iter    6   |   diff: 0.07028   |   V((0, 0)) = 0.140   V((0, 1)) = 0.191   V((0, 2)) = 0.333   V((0, 3)) = 0.191   V((1, 0)) = 0.240   V((1, 1)) = 0.000   V((1, 2)) = 0.453   V((1, 3)) = 0.000   V((2, 0)) = 0.420   V((2, 1)) = 0.620   V((2, 2)) = 0.692   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.777   V((3, 2)) = 0.930   V((3, 3)) = 0.000
# iter    7   |   diff: 0.06030   |   V((0, 0)) = 0.199   V((0, 1)) = 0.246   V((0, 2)) = 0.349   V((0, 3)) = 0.246   V((1, 0)) = 0.310   V((1, 1)) = 0.000   V((1, 2)) = 0.467   V((1, 3)) = 0.000   V((2, 0)) = 0.446   V((2, 1)) = 0.649   V((2, 2)) = 0.697   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.785   V((3, 2)) = 0.932   V((3, 3)) = 0.000
# iter    8   |   diff: 0.02594   |   V((0, 0)) = 0.260   V((0, 1)) = 0.263   V((0, 2)) = 0.371   V((0, 3)) = 0.263   V((1, 0)) = 0.336   V((1, 1)) = 0.000   V((1, 2)) = 0.471   V((1, 3)) = 0.000   V((2, 0)) = 0.473   V((2, 1)) = 0.658   V((2, 2)) = 0.702   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.791   V((3, 2)) = 0.933   V((3, 3)) = 0.000
# iter    9   |   diff: 0.01918   |   V((0, 0)) = 0.285   V((0, 1)) = 0.280   V((0, 2)) = 0.377   V((0, 3)) = 0.280   V((1, 0)) = 0.357   V((1, 1)) = 0.000   V((1, 2)) = 0.474   V((1, 3)) = 0.000   V((2, 0)) = 0.482   V((2, 1)) = 0.666   V((2, 2)) = 0.704   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.793   V((3, 2)) = 0.934   V((3, 3)) = 0.000
# iter   10   |   diff: 0.00858   |   V((0, 0)) = 0.305   V((0, 1)) = 0.286   V((0, 2)) = 0.383   V((0, 3)) = 0.286   V((1, 0)) = 0.366   V((1, 1)) = 0.000   V((1, 2)) = 0.475   V((1, 3)) = 0.000   V((2, 0)) = 0.490   V((2, 1)) = 0.669   V((2, 2)) = 0.705   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.795   V((3, 2)) = 0.934   V((3, 3)) = 0.000
# iter   11   |   diff: 0.00560   |   V((0, 0)) = 0.313   V((0, 1)) = 0.291   V((0, 2)) = 0.385   V((0, 3)) = 0.291   V((1, 0)) = 0.372   V((1, 1)) = 0.000   V((1, 2)) = 0.476   V((1, 3)) = 0.000   V((2, 0)) = 0.493   V((2, 1)) = 0.671   V((2, 2)) = 0.706   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.795   V((3, 2)) = 0.934   V((3, 3)) = 0.000
# iter   12   |   diff: 0.00260   |   V((0, 0)) = 0.319   V((0, 1)) = 0.293   V((0, 2)) = 0.387   V((0, 3)) = 0.293   V((1, 0)) = 0.374   V((1, 1)) = 0.000   V((1, 2)) = 0.476   V((1, 3)) = 0.000   V((2, 0)) = 0.495   V((2, 1)) = 0.672   V((2, 2)) = 0.706   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.796   V((3, 2)) = 0.935   V((3, 3)) = 0.000
# iter   13   |   diff: 0.00159   |   V((0, 0)) = 0.321   V((0, 1)) = 0.294   V((0, 2)) = 0.387   V((0, 3)) = 0.294   V((1, 0)) = 0.376   V((1, 1)) = 0.000   V((1, 2)) = 0.477   V((1, 3)) = 0.000   V((2, 0)) = 0.495   V((2, 1)) = 0.672   V((2, 2)) = 0.706   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.796   V((3, 2)) = 0.935   V((3, 3)) = 0.000
# iter   14   |   diff: 0.00076   |   V((0, 0)) = 0.323   V((0, 1)) = 0.295   V((0, 2)) = 0.388   V((0, 3)) = 0.295   V((1, 0)) = 0.377   V((1, 1)) = 0.000   V((1, 2)) = 0.477   V((1, 3)) = 0.000   V((2, 0)) = 0.496   V((2, 1)) = 0.672   V((2, 2)) = 0.706   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.796   V((3, 2)) = 0.935   V((3, 3)) = 0.000
# iter   15   |   diff: 0.00045   |   V((0, 0)) = 0.324   V((0, 1)) = 0.295   V((0, 2)) = 0.388   V((0, 3)) = 0.295   V((1, 0)) = 0.377   V((1, 1)) = 0.000   V((1, 2)) = 0.477   V((1, 3)) = 0.000   V((2, 0)) = 0.496   V((2, 1)) = 0.673   V((2, 2)) = 0.707   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.796   V((3, 2)) = 0.935   V((3, 3)) = 0.000
# iter   16   |   diff: 0.00022   |   V((0, 0)) = 0.324   V((0, 1)) = 0.295   V((0, 2)) = 0.388   V((0, 3)) = 0.295   V((1, 0)) = 0.377   V((1, 1)) = 0.000   V((1, 2)) = 0.477   V((1, 3)) = 0.000   V((2, 0)) = 0.496   V((2, 1)) = 0.673   V((2, 2)) = 0.707   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.796   V((3, 2)) = 0.935   V((3, 3)) = 0.000
# iter   17   |   diff: 0.00012   |   V((0, 0)) = 0.324   V((0, 1)) = 0.295   V((0, 2)) = 0.388   V((0, 3)) = 0.295   V((1, 0)) = 0.378   V((1, 1)) = 0.000   V((1, 2)) = 0.477   V((1, 3)) = 0.000   V((2, 0)) = 0.497   V((2, 1)) = 0.673   V((2, 2)) = 0.707   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.796   V((3, 2)) = 0.935   V((3, 3)) = 0.000
# iter   18   |   diff: 0.00006   |   V((0, 0)) = 0.325   V((0, 1)) = 0.295   V((0, 2)) = 0.388   V((0, 3)) = 0.295   V((1, 0)) = 0.378   V((1, 1)) = 0.000   V((1, 2)) = 0.477   V((1, 3)) = 0.000   V((2, 0)) = 0.497   V((2, 1)) = 0.673   V((2, 2)) = 0.707   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.796   V((3, 2)) = 0.935   V((3, 3)) = 0.000
# iter   19   |   diff: 0.00003   |   V((0, 0)) = 0.325   V((0, 1)) = 0.295   V((0, 2)) = 0.388   V((0, 3)) = 0.295   V((1, 0)) = 0.378   V((1, 1)) = 0.000   V((1, 2)) = 0.477   V((1, 3)) = 0.000   V((2, 0)) = 0.497   V((2, 1)) = 0.673   V((2, 2)) = 0.707   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.796   V((3, 2)) = 0.935   V((3, 3)) = 0.000
# iter   20   |   diff: 0.00002   |   V((0, 0)) = 0.325   V((0, 1)) = 0.295   V((0, 2)) = 0.388   V((0, 3)) = 0.295   V((1, 0)) = 0.378   V((1, 1)) = 0.000   V((1, 2)) = 0.477   V((1, 3)) = 0.000   V((2, 0)) = 0.497   V((2, 1)) = 0.673   V((2, 2)) = 0.707   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.796   V((3, 2)) = 0.935   V((3, 3)) = 0.000
# iter   21   |   diff: 0.00001   |   V((0, 0)) = 0.325   V((0, 1)) = 0.295   V((0, 2)) = 0.388   V((0, 3)) = 0.295   V((1, 0)) = 0.378   V((1, 1)) = 0.000   V((1, 2)) = 0.477   V((1, 3)) = 0.000   V((2, 0)) = 0.497   V((2, 1)) = 0.673   V((2, 2)) = 0.707   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.796   V((3, 2)) = 0.935   V((3, 3)) = 0.000
# average reward:  0.648
# Well done!

# %%
mdp = FrozenLakeEnv(slip_chance=0.25)
state_values, policy = policy_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    rewards = []
    for t in range(100):
        s, r, done, _ = mdp.step(policy[s])
        rewards.append(r)
        if done:
            break
    total_rewards.append(np.sum(rewards))

print("average reward: ", np.mean(total_rewards))
assert(0.6 <= np.mean(total_rewards) <= 0.7)
print("Well done!")
# Out:
# iter    0   |   diff: 0.85746   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 0.000   V((3, 3)) = 0.000
# iter    1   |   diff: 0.77979   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.001   V((0, 3)) = 0.001   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.011   V((1, 3)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.098   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 0.857   V((3, 3)) = 0.000
# iter    2   |   diff: 0.47339   |   V((0, 0)) = 0.037   V((0, 1)) = 0.289   V((0, 2)) = 0.380   V((0, 3)) = 0.289   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.467   V((1, 3)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.555   V((2, 2)) = 0.692   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.780   V((3, 2)) = 0.933   V((3, 3)) = 0.000
# iter    3   |   diff: 0.18868   |   V((0, 0)) = 0.249   V((0, 1)) = 0.295   V((0, 2)) = 0.388   V((0, 3)) = 0.295   V((1, 0)) = 0.189   V((1, 1)) = 0.000   V((1, 2)) = 0.477   V((1, 3)) = 0.000   V((2, 0)) = 0.473   V((2, 1)) = 0.670   V((2, 2)) = 0.706   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.796   V((3, 2)) = 0.935   V((3, 3)) = 0.000
# iter    4   |   diff: 0.05216   |   V((0, 0)) = 0.273   V((0, 1)) = 0.295   V((0, 2)) = 0.388   V((0, 3)) = 0.295   V((1, 0)) = 0.378   V((1, 1)) = 0.000   V((1, 2)) = 0.477   V((1, 3)) = 0.000   V((2, 0)) = 0.497   V((2, 1)) = 0.673   V((2, 2)) = 0.707   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.796   V((3, 2)) = 0.935   V((3, 3)) = 0.000
# iter    5   |   diff: 0.00000   |   V((0, 0)) = 0.325   V((0, 1)) = 0.295   V((0, 2)) = 0.388   V((0, 3)) = 0.295   V((1, 0)) = 0.378   V((1, 1)) = 0.000   V((1, 2)) = 0.477   V((1, 3)) = 0.000   V((2, 0)) = 0.497   V((2, 1)) = 0.673   V((2, 2)) = 0.707   V((2, 3)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.796   V((3, 2)) = 0.935   V((3, 3)) = 0.000
# average reward:  0.644
# Well done!

# %%
print("VI large FrozenLake")
mdp = FrozenLakeEnv(map_name='8x8', slip_chance=0.1)
state_values = value_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    rewards = []
    for t in range(100):
        s, r, done, _ = mdp.step(
            get_optimal_action(mdp, state_values, s, gamma))
        rewards.append(r)
        if done:
            break
    total_rewards.append(np.sum(rewards))

print("average reward: ", np.mean(total_rewards))
# Out:
# VI large FrozenLake
# iter    0   |   diff: 0.90000   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((0, 4)) = 0.000   V((0, 5)) = 0.000   V((0, 6)) = 0.000   V((0, 7)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((1, 4)) = 0.000   V((1, 5)) = 0.000   V((1, 6)) = 0.000   V((1, 7)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((2, 4)) = 0.000   V((2, 5)) = 0.000   V((2, 6)) = 0.000   V((2, 7)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 0.000   V((3, 3)) = 0.000   V((3, 4)) = 0.000   V((3, 5)) = 0.000   V((3, 6)) = 0.000   V((3, 7)) = 0.000   V((4, 0)) = 0.000   V((4, 1)) = 0.000   V((4, 2)) = 0.000   V((4, 3)) = 0.000   V((4, 4)) = 0.000   V((4, 5)) = 0.000   V((4, 6)) = 0.000   V((4, 7)) = 0.000   V((5, 0)) = 0.000   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.000   V((5, 4)) = 0.000   V((5, 5)) = 0.000   V((5, 6)) = 0.000   V((5, 7)) = 0.000   V((6, 0)) = 0.000   V((6, 1)) = 0.000   V((6, 2)) = 0.000   V((6, 3)) = 0.000   V((6, 4)) = 0.000   V((6, 5)) = 0.000   V((6, 6)) = 0.000   V((6, 7)) = 0.000   V((7, 0)) = 0.000   V((7, 1)) = 0.000   V((7, 2)) = 0.000   V((7, 3)) = 0.000   V((7, 4)) = 0.000   V((7, 5)) = 0.000   V((7, 6)) = 0.000   V((7, 7)) = 0.000
# iter    1   |   diff: 0.72900   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((0, 4)) = 0.000   V((0, 5)) = 0.000   V((0, 6)) = 0.000   V((0, 7)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((1, 4)) = 0.000   V((1, 5)) = 0.000   V((1, 6)) = 0.000   V((1, 7)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((2, 4)) = 0.000   V((2, 5)) = 0.000   V((2, 6)) = 0.000   V((2, 7)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 0.000   V((3, 3)) = 0.000   V((3, 4)) = 0.000   V((3, 5)) = 0.000   V((3, 6)) = 0.000   V((3, 7)) = 0.000   V((4, 0)) = 0.000   V((4, 1)) = 0.000   V((4, 2)) = 0.000   V((4, 3)) = 0.000   V((4, 4)) = 0.000   V((4, 5)) = 0.000   V((4, 6)) = 0.000   V((4, 7)) = 0.000   V((5, 0)) = 0.000   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.000   V((5, 4)) = 0.000   V((5, 5)) = 0.000   V((5, 6)) = 0.000   V((5, 7)) = 0.000   V((6, 0)) = 0.000   V((6, 1)) = 0.000   V((6, 2)) = 0.000   V((6, 3)) = 0.000   V((6, 4)) = 0.000   V((6, 5)) = 0.000   V((6, 6)) = 0.000   V((6, 7)) = 0.900   V((7, 0)) = 0.000   V((7, 1)) = 0.000   V((7, 2)) = 0.000   V((7, 3)) = 0.000   V((7, 4)) = 0.000   V((7, 5)) = 0.000   V((7, 6)) = 0.900   V((7, 7)) = 0.000
# iter    2   |   diff: 0.59049   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((0, 4)) = 0.000   V((0, 5)) = 0.000   V((0, 6)) = 0.000   V((0, 7)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((1, 4)) = 0.000   V((1, 5)) = 0.000   V((1, 6)) = 0.000   V((1, 7)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((2, 4)) = 0.000   V((2, 5)) = 0.000   V((2, 6)) = 0.000   V((2, 7)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 0.000   V((3, 3)) = 0.000   V((3, 4)) = 0.000   V((3, 5)) = 0.000   V((3, 6)) = 0.000   V((3, 7)) = 0.000   V((4, 0)) = 0.000   V((4, 1)) = 0.000   V((4, 2)) = 0.000   V((4, 3)) = 0.000   V((4, 4)) = 0.000   V((4, 5)) = 0.000   V((4, 6)) = 0.000   V((4, 7)) = 0.000   V((5, 0)) = 0.000   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.000   V((5, 4)) = 0.000   V((5, 5)) = 0.000   V((5, 6)) = 0.000   V((5, 7)) = 0.729   V((6, 0)) = 0.000   V((6, 1)) = 0.000   V((6, 2)) = 0.000   V((6, 3)) = 0.000   V((6, 4)) = 0.000   V((6, 5)) = 0.000   V((6, 6)) = 0.000   V((6, 7)) = 0.941   V((7, 0)) = 0.000   V((7, 1)) = 0.000   V((7, 2)) = 0.000   V((7, 3)) = 0.000   V((7, 4)) = 0.000   V((7, 5)) = 0.729   V((7, 6)) = 0.941   V((7, 7)) = 0.000
# iter    3   |   diff: 0.47830   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((0, 4)) = 0.000   V((0, 5)) = 0.000   V((0, 6)) = 0.000   V((0, 7)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((1, 4)) = 0.000   V((1, 5)) = 0.000   V((1, 6)) = 0.000   V((1, 7)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((2, 4)) = 0.000   V((2, 5)) = 0.000   V((2, 6)) = 0.000   V((2, 7)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 0.000   V((3, 3)) = 0.000   V((3, 4)) = 0.000   V((3, 5)) = 0.000   V((3, 6)) = 0.000   V((3, 7)) = 0.000   V((4, 0)) = 0.000   V((4, 1)) = 0.000   V((4, 2)) = 0.000   V((4, 3)) = 0.000   V((4, 4)) = 0.000   V((4, 5)) = 0.000   V((4, 6)) = 0.000   V((4, 7)) = 0.590   V((5, 0)) = 0.000   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.000   V((5, 4)) = 0.000   V((5, 5)) = 0.000   V((5, 6)) = 0.000   V((5, 7)) = 0.795   V((6, 0)) = 0.000   V((6, 1)) = 0.000   V((6, 2)) = 0.000   V((6, 3)) = 0.000   V((6, 4)) = 0.000   V((6, 5)) = 0.590   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.000   V((7, 1)) = 0.000   V((7, 2)) = 0.000   V((7, 3)) = 0.000   V((7, 4)) = 0.590   V((7, 5)) = 0.795   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter    4   |   diff: 0.40894   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((0, 4)) = 0.000   V((0, 5)) = 0.000   V((0, 6)) = 0.000   V((0, 7)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((1, 4)) = 0.000   V((1, 5)) = 0.000   V((1, 6)) = 0.000   V((1, 7)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((2, 4)) = 0.000   V((2, 5)) = 0.000   V((2, 6)) = 0.000   V((2, 7)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 0.000   V((3, 3)) = 0.000   V((3, 4)) = 0.000   V((3, 5)) = 0.000   V((3, 6)) = 0.000   V((3, 7)) = 0.478   V((4, 0)) = 0.000   V((4, 1)) = 0.000   V((4, 2)) = 0.000   V((4, 3)) = 0.000   V((4, 4)) = 0.000   V((4, 5)) = 0.000   V((4, 6)) = 0.478   V((4, 7)) = 0.670   V((5, 0)) = 0.000   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.000   V((5, 4)) = 0.000   V((5, 5)) = 0.478   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.000   V((6, 1)) = 0.000   V((6, 2)) = 0.000   V((6, 3)) = 0.000   V((6, 4)) = 0.000   V((6, 5)) = 0.644   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.000   V((7, 1)) = 0.000   V((7, 2)) = 0.000   V((7, 3)) = 0.000   V((7, 4)) = 0.670   V((7, 5)) = 0.826   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter    5   |   diff: 0.34868   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((0, 4)) = 0.000   V((0, 5)) = 0.000   V((0, 6)) = 0.000   V((0, 7)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((1, 4)) = 0.000   V((1, 5)) = 0.000   V((1, 6)) = 0.000   V((1, 7)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((2, 4)) = 0.000   V((2, 5)) = 0.000   V((2, 6)) = 0.000   V((2, 7)) = 0.387   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 0.000   V((3, 3)) = 0.000   V((3, 4)) = 0.000   V((3, 5)) = 0.000   V((3, 6)) = 0.409   V((3, 7)) = 0.564   V((4, 0)) = 0.000   V((4, 1)) = 0.000   V((4, 2)) = 0.000   V((4, 3)) = 0.000   V((4, 4)) = 0.000   V((4, 5)) = 0.409   V((4, 6)) = 0.543   V((4, 7)) = 0.699   V((5, 0)) = 0.000   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.000   V((5, 4)) = 0.387   V((5, 5)) = 0.521   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.000   V((6, 1)) = 0.000   V((6, 2)) = 0.000   V((6, 3)) = 0.000   V((6, 4)) = 0.000   V((6, 5)) = 0.669   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.000   V((7, 1)) = 0.000   V((7, 2)) = 0.000   V((7, 3)) = 0.000   V((7, 4)) = 0.699   V((7, 5)) = 0.829   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter    6   |   diff: 0.29655   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((0, 4)) = 0.000   V((0, 5)) = 0.000   V((0, 6)) = 0.000   V((0, 7)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((1, 4)) = 0.000   V((1, 5)) = 0.000   V((1, 6)) = 0.000   V((1, 7)) = 0.314   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((2, 4)) = 0.000   V((2, 5)) = 0.000   V((2, 6)) = 0.349   V((2, 7)) = 0.475   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 0.000   V((3, 3)) = 0.000   V((3, 4)) = 0.000   V((3, 5)) = 0.000   V((3, 6)) = 0.482   V((3, 7)) = 0.610   V((4, 0)) = 0.000   V((4, 1)) = 0.000   V((4, 2)) = 0.000   V((4, 3)) = 0.000   V((4, 4)) = 0.349   V((4, 5)) = 0.463   V((4, 6)) = 0.585   V((4, 7)) = 0.703   V((5, 0)) = 0.000   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.314   V((5, 4)) = 0.422   V((5, 5)) = 0.559   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.000   V((6, 1)) = 0.000   V((6, 2)) = 0.000   V((6, 3)) = 0.000   V((6, 4)) = 0.000   V((6, 5)) = 0.672   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.000   V((7, 1)) = 0.000   V((7, 2)) = 0.000   V((7, 3)) = 0.000   V((7, 4)) = 0.703   V((7, 5)) = 0.831   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter    7   |   diff: 0.25292   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((0, 4)) = 0.000   V((0, 5)) = 0.000   V((0, 6)) = 0.000   V((0, 7)) = 0.254   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((1, 4)) = 0.000   V((1, 5)) = 0.000   V((1, 6)) = 0.297   V((1, 7)) = 0.399   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((2, 4)) = 0.000   V((2, 5)) = 0.282   V((2, 6)) = 0.411   V((2, 7)) = 0.531   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 0.000   V((3, 3)) = 0.000   V((3, 4)) = 0.282   V((3, 5)) = 0.000   V((3, 6)) = 0.536   V((3, 7)) = 0.619   V((4, 0)) = 0.000   V((4, 1)) = 0.000   V((4, 2)) = 0.000   V((4, 3)) = 0.000   V((4, 4)) = 0.394   V((4, 5)) = 0.499   V((4, 6)) = 0.591   V((4, 7)) = 0.705   V((5, 0)) = 0.000   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.342   V((5, 4)) = 0.469   V((5, 5)) = 0.563   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.000   V((6, 1)) = 0.000   V((6, 2)) = 0.000   V((6, 3)) = 0.254   V((6, 4)) = 0.000   V((6, 5)) = 0.673   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.000   V((7, 1)) = 0.000   V((7, 2)) = 0.000   V((7, 3)) = 0.000   V((7, 4)) = 0.705   V((7, 5)) = 0.831   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter    8   |   diff: 0.21619   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((0, 4)) = 0.000   V((0, 5)) = 0.000   V((0, 6)) = 0.252   V((0, 7)) = 0.334   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((1, 4)) = 0.000   V((1, 5)) = 0.253   V((1, 6)) = 0.351   V((1, 7)) = 0.461   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((2, 4)) = 0.241   V((2, 5)) = 0.333   V((2, 6)) = 0.471   V((2, 7)) = 0.544   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 0.000   V((3, 3)) = 0.229   V((3, 4)) = 0.319   V((3, 5)) = 0.000   V((3, 6)) = 0.546   V((3, 7)) = 0.623   V((4, 0)) = 0.000   V((4, 1)) = 0.000   V((4, 2)) = 0.000   V((4, 3)) = 0.000   V((4, 4)) = 0.438   V((4, 5)) = 0.504   V((4, 6)) = 0.595   V((4, 7)) = 0.706   V((5, 0)) = 0.000   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.391   V((5, 4)) = 0.474   V((5, 5)) = 0.566   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.000   V((6, 1)) = 0.000   V((6, 2)) = 0.206   V((6, 3)) = 0.277   V((6, 4)) = 0.000   V((6, 5)) = 0.673   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.000   V((7, 1)) = 0.000   V((7, 2)) = 0.000   V((7, 3)) = 0.000   V((7, 4)) = 0.705   V((7, 5)) = 0.831   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter    9   |   diff: 0.18482   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((0, 4)) = 0.000   V((0, 5)) = 0.216   V((0, 6)) = 0.300   V((0, 7)) = 0.400   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((1, 4)) = 0.216   V((1, 5)) = 0.299   V((1, 6)) = 0.413   V((1, 7)) = 0.477   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((2, 4)) = 0.284   V((2, 5)) = 0.393   V((2, 6)) = 0.482   V((2, 7)) = 0.551   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 0.185   V((3, 3)) = 0.259   V((3, 4)) = 0.365   V((3, 5)) = 0.000   V((3, 6)) = 0.553   V((3, 7)) = 0.624   V((4, 0)) = 0.000   V((4, 1)) = 0.000   V((4, 2)) = 0.000   V((4, 3)) = 0.000   V((4, 4)) = 0.444   V((4, 5)) = 0.508   V((4, 6)) = 0.596   V((4, 7)) = 0.706   V((5, 0)) = 0.000   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.396   V((5, 4)) = 0.478   V((5, 5)) = 0.567   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.000   V((6, 1)) = 0.000   V((6, 2)) = 0.224   V((6, 3)) = 0.326   V((6, 4)) = 0.000   V((6, 5)) = 0.673   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.000   V((7, 1)) = 0.000   V((7, 2)) = 0.167   V((7, 3)) = 0.000   V((7, 4)) = 0.705   V((7, 5)) = 0.831   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter   10   |   diff: 0.15757   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((0, 4)) = 0.185   V((0, 5)) = 0.266   V((0, 6)) = 0.363   V((0, 7)) = 0.418   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.175   V((1, 4)) = 0.255   V((1, 5)) = 0.362   V((1, 6)) = 0.425   V((1, 7)) = 0.486   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.150   V((2, 3)) = 0.000   V((2, 4)) = 0.344   V((2, 5)) = 0.404   V((2, 6)) = 0.490   V((2, 7)) = 0.552   V((3, 0)) = 0.000   V((3, 1)) = 0.150   V((3, 2)) = 0.209   V((3, 3)) = 0.295   V((3, 4)) = 0.371   V((3, 5)) = 0.000   V((3, 6)) = 0.554   V((3, 7)) = 0.625   V((4, 0)) = 0.000   V((4, 1)) = 0.000   V((4, 2)) = 0.150   V((4, 3)) = 0.000   V((4, 4)) = 0.449   V((4, 5)) = 0.508   V((4, 6)) = 0.597   V((4, 7)) = 0.706   V((5, 0)) = 0.000   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.402   V((5, 4)) = 0.479   V((5, 5)) = 0.567   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.000   V((6, 1)) = 0.000   V((6, 2)) = 0.272   V((6, 3)) = 0.331   V((6, 4)) = 0.000   V((6, 5)) = 0.673   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.000   V((7, 1)) = 0.135   V((7, 2)) = 0.182   V((7, 3)) = 0.000   V((7, 4)) = 0.705   V((7, 5)) = 0.831   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter   11   |   diff: 0.13430   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.158   V((0, 4)) = 0.235   V((0, 5)) = 0.322   V((0, 6)) = 0.375   V((0, 7)) = 0.429   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.148   V((1, 3)) = 0.207   V((1, 4)) = 0.317   V((1, 5)) = 0.375   V((1, 6)) = 0.435   V((1, 7)) = 0.488   V((2, 0)) = 0.000   V((2, 1)) = 0.128   V((2, 2)) = 0.170   V((2, 3)) = 0.000   V((2, 4)) = 0.355   V((2, 5)) = 0.413   V((2, 6)) = 0.492   V((2, 7)) = 0.553   V((3, 0)) = 0.122   V((3, 1)) = 0.170   V((3, 2)) = 0.253   V((3, 3)) = 0.301   V((3, 4)) = 0.377   V((3, 5)) = 0.000   V((3, 6)) = 0.555   V((3, 7)) = 0.625   V((4, 0)) = 0.000   V((4, 1)) = 0.128   V((4, 2)) = 0.170   V((4, 3)) = 0.000   V((4, 4)) = 0.450   V((4, 5)) = 0.509   V((4, 6)) = 0.597   V((4, 7)) = 0.706   V((5, 0)) = 0.000   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.403   V((5, 4)) = 0.479   V((5, 5)) = 0.567   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.000   V((6, 1)) = 0.000   V((6, 2)) = 0.276   V((6, 3)) = 0.338   V((6, 4)) = 0.000   V((6, 5)) = 0.673   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.109   V((7, 1)) = 0.153   V((7, 2)) = 0.226   V((7, 3)) = 0.000   V((7, 4)) = 0.705   V((7, 5)) = 0.831   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter   12   |   diff: 0.11445   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.134   V((0, 3)) = 0.207   V((0, 4)) = 0.286   V((0, 5)) = 0.335   V((0, 6)) = 0.386   V((0, 7)) = 0.432   V((1, 0)) = 0.000   V((1, 1)) = 0.126   V((1, 2)) = 0.175   V((1, 3)) = 0.264   V((1, 4)) = 0.330   V((1, 5)) = 0.386   V((1, 6)) = 0.437   V((1, 7)) = 0.490   V((2, 0)) = 0.109   V((2, 1)) = 0.145   V((2, 2)) = 0.211   V((2, 3)) = 0.000   V((2, 4)) = 0.366   V((2, 5)) = 0.415   V((2, 6)) = 0.493   V((2, 7)) = 0.553   V((3, 0)) = 0.137   V((3, 1)) = 0.216   V((3, 2)) = 0.259   V((3, 3)) = 0.306   V((3, 4)) = 0.378   V((3, 5)) = 0.000   V((3, 6)) = 0.555   V((3, 7)) = 0.625   V((4, 0)) = 0.109   V((4, 1)) = 0.145   V((4, 2)) = 0.211   V((4, 3)) = 0.000   V((4, 4)) = 0.451   V((4, 5)) = 0.509   V((4, 6)) = 0.597   V((4, 7)) = 0.706   V((5, 0)) = 0.000   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.403   V((5, 4)) = 0.479   V((5, 5)) = 0.567   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.089   V((6, 1)) = 0.000   V((6, 2)) = 0.284   V((6, 3)) = 0.339   V((6, 4)) = 0.000   V((6, 5)) = 0.673   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.129   V((7, 1)) = 0.190   V((7, 2)) = 0.231   V((7, 3)) = 0.000   V((7, 4)) = 0.705   V((7, 5)) = 0.831   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter   13   |   diff: 0.09751   |   V((0, 0)) = 0.000   V((0, 1)) = 0.114   V((0, 2)) = 0.181   V((0, 3)) = 0.253   V((0, 4)) = 0.299   V((0, 5)) = 0.345   V((0, 6)) = 0.389   V((0, 7)) = 0.433   V((1, 0)) = 0.107   V((1, 1)) = 0.148   V((1, 2)) = 0.229   V((1, 3)) = 0.277   V((1, 4)) = 0.342   V((1, 5)) = 0.388   V((1, 6)) = 0.439   V((1, 7)) = 0.490   V((2, 0)) = 0.124   V((2, 1)) = 0.190   V((2, 2)) = 0.216   V((2, 3)) = 0.000   V((2, 4)) = 0.368   V((2, 5)) = 0.417   V((2, 6)) = 0.493   V((2, 7)) = 0.553   V((3, 0)) = 0.185   V((3, 1)) = 0.223   V((3, 2)) = 0.266   V((3, 3)) = 0.306   V((3, 4)) = 0.379   V((3, 5)) = 0.000   V((3, 6)) = 0.555   V((3, 7)) = 0.625   V((4, 0)) = 0.124   V((4, 1)) = 0.190   V((4, 2)) = 0.216   V((4, 3)) = 0.000   V((4, 4)) = 0.451   V((4, 5)) = 0.509   V((4, 6)) = 0.597   V((4, 7)) = 0.706   V((5, 0)) = 0.089   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.404   V((5, 4)) = 0.479   V((5, 5)) = 0.567   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.109   V((6, 1)) = 0.000   V((6, 2)) = 0.285   V((6, 3)) = 0.340   V((6, 4)) = 0.000   V((6, 5)) = 0.673   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.164   V((7, 1)) = 0.195   V((7, 2)) = 0.238   V((7, 3)) = 0.000   V((7, 4)) = 0.705   V((7, 5)) = 0.831   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter   14   |   diff: 0.04772   |   V((0, 0)) = 0.098   V((0, 1)) = 0.159   V((0, 2)) = 0.223   V((0, 3)) = 0.266   V((0, 4)) = 0.309   V((0, 5)) = 0.348   V((0, 6)) = 0.390   V((0, 7)) = 0.434   V((1, 0)) = 0.126   V((1, 1)) = 0.200   V((1, 2)) = 0.242   V((1, 3)) = 0.288   V((1, 4)) = 0.344   V((1, 5)) = 0.390   V((1, 6)) = 0.439   V((1, 7)) = 0.490   V((2, 0)) = 0.167   V((2, 1)) = 0.196   V((2, 2)) = 0.224   V((2, 3)) = 0.000   V((2, 4)) = 0.370   V((2, 5)) = 0.417   V((2, 6)) = 0.493   V((2, 7)) = 0.553   V((3, 0)) = 0.192   V((3, 1)) = 0.233   V((3, 2)) = 0.268   V((3, 3)) = 0.307   V((3, 4)) = 0.379   V((3, 5)) = 0.000   V((3, 6)) = 0.555   V((3, 7)) = 0.625   V((4, 0)) = 0.166   V((4, 1)) = 0.196   V((4, 2)) = 0.224   V((4, 3)) = 0.000   V((4, 4)) = 0.451   V((4, 5)) = 0.509   V((4, 6)) = 0.597   V((4, 7)) = 0.706   V((5, 0)) = 0.104   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.404   V((5, 4)) = 0.479   V((5, 5)) = 0.567   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.137   V((6, 1)) = 0.000   V((6, 2)) = 0.286   V((6, 3)) = 0.340   V((6, 4)) = 0.000   V((6, 5)) = 0.673   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.171   V((7, 1)) = 0.202   V((7, 2)) = 0.239   V((7, 3)) = 0.000   V((7, 4)) = 0.705   V((7, 5)) = 0.831   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter   15   |   diff: 0.03479   |   V((0, 0)) = 0.139   V((0, 1)) = 0.197   V((0, 2)) = 0.237   V((0, 3)) = 0.275   V((0, 4)) = 0.311   V((0, 5)) = 0.349   V((0, 6)) = 0.391   V((0, 7)) = 0.434   V((1, 0)) = 0.174   V((1, 1)) = 0.212   V((1, 2)) = 0.254   V((1, 3)) = 0.291   V((1, 4)) = 0.346   V((1, 5)) = 0.390   V((1, 6)) = 0.439   V((1, 7)) = 0.490   V((2, 0)) = 0.173   V((2, 1)) = 0.206   V((2, 2)) = 0.226   V((2, 3)) = 0.000   V((2, 4)) = 0.370   V((2, 5)) = 0.417   V((2, 6)) = 0.493   V((2, 7)) = 0.553   V((3, 0)) = 0.204   V((3, 1)) = 0.234   V((3, 2)) = 0.269   V((3, 3)) = 0.307   V((3, 4)) = 0.379   V((3, 5)) = 0.000   V((3, 6)) = 0.555   V((3, 7)) = 0.625   V((4, 0)) = 0.172   V((4, 1)) = 0.206   V((4, 2)) = 0.226   V((4, 3)) = 0.000   V((4, 4)) = 0.451   V((4, 5)) = 0.509   V((4, 6)) = 0.597   V((4, 7)) = 0.706   V((5, 0)) = 0.139   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.404   V((5, 4)) = 0.479   V((5, 5)) = 0.567   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.144   V((6, 1)) = 0.000   V((6, 2)) = 0.286   V((6, 3)) = 0.340   V((6, 4)) = 0.000   V((6, 5)) = 0.673   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.177   V((7, 1)) = 0.203   V((7, 2)) = 0.241   V((7, 3)) = 0.000   V((7, 4)) = 0.705   V((7, 5)) = 0.831   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter   16   |   diff: 0.01283   |   V((0, 0)) = 0.173   V((0, 1)) = 0.210   V((0, 2)) = 0.245   V((0, 3)) = 0.278   V((0, 4)) = 0.313   V((0, 5)) = 0.350   V((0, 6)) = 0.391   V((0, 7)) = 0.434   V((1, 0)) = 0.186   V((1, 1)) = 0.224   V((1, 2)) = 0.256   V((1, 3)) = 0.293   V((1, 4)) = 0.347   V((1, 5)) = 0.390   V((1, 6)) = 0.439   V((1, 7)) = 0.490   V((2, 0)) = 0.184   V((2, 1)) = 0.208   V((2, 2)) = 0.227   V((2, 3)) = 0.000   V((2, 4)) = 0.371   V((2, 5)) = 0.417   V((2, 6)) = 0.494   V((2, 7)) = 0.553   V((3, 0)) = 0.205   V((3, 1)) = 0.236   V((3, 2)) = 0.269   V((3, 3)) = 0.307   V((3, 4)) = 0.379   V((3, 5)) = 0.000   V((3, 6)) = 0.555   V((3, 7)) = 0.625   V((4, 0)) = 0.182   V((4, 1)) = 0.208   V((4, 2)) = 0.227   V((4, 3)) = 0.000   V((4, 4)) = 0.451   V((4, 5)) = 0.509   V((4, 6)) = 0.597   V((4, 7)) = 0.706   V((5, 0)) = 0.146   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.404   V((5, 4)) = 0.479   V((5, 5)) = 0.567   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.150   V((6, 1)) = 0.000   V((6, 2)) = 0.286   V((6, 3)) = 0.340   V((6, 4)) = 0.000   V((6, 5)) = 0.673   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.179   V((7, 1)) = 0.204   V((7, 2)) = 0.241   V((7, 3)) = 0.000   V((7, 4)) = 0.705   V((7, 5)) = 0.831   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter   17   |   diff: 0.00734   |   V((0, 0)) = 0.186   V((0, 1)) = 0.218   V((0, 2)) = 0.247   V((0, 3)) = 0.279   V((0, 4)) = 0.313   V((0, 5)) = 0.350   V((0, 6)) = 0.391   V((0, 7)) = 0.434   V((1, 0)) = 0.197   V((1, 1)) = 0.227   V((1, 2)) = 0.258   V((1, 3)) = 0.293   V((1, 4)) = 0.347   V((1, 5)) = 0.390   V((1, 6)) = 0.439   V((1, 7)) = 0.490   V((2, 0)) = 0.186   V((2, 1)) = 0.210   V((2, 2)) = 0.227   V((2, 3)) = 0.000   V((2, 4)) = 0.371   V((2, 5)) = 0.417   V((2, 6)) = 0.494   V((2, 7)) = 0.553   V((3, 0)) = 0.208   V((3, 1)) = 0.237   V((3, 2)) = 0.269   V((3, 3)) = 0.307   V((3, 4)) = 0.379   V((3, 5)) = 0.000   V((3, 6)) = 0.555   V((3, 7)) = 0.625   V((4, 0)) = 0.184   V((4, 1)) = 0.210   V((4, 2)) = 0.227   V((4, 3)) = 0.000   V((4, 4)) = 0.451   V((4, 5)) = 0.509   V((4, 6)) = 0.597   V((4, 7)) = 0.706   V((5, 0)) = 0.154   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.404   V((5, 4)) = 0.479   V((5, 5)) = 0.567   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.152   V((6, 1)) = 0.000   V((6, 2)) = 0.286   V((6, 3)) = 0.340   V((6, 4)) = 0.000   V((6, 5)) = 0.673   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.180   V((7, 1)) = 0.204   V((7, 2)) = 0.241   V((7, 3)) = 0.000   V((7, 4)) = 0.705   V((7, 5)) = 0.831   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter   18   |   diff: 0.00255   |   V((0, 0)) = 0.194   V((0, 1)) = 0.220   V((0, 2)) = 0.249   V((0, 3)) = 0.279   V((0, 4)) = 0.313   V((0, 5)) = 0.350   V((0, 6)) = 0.391   V((0, 7)) = 0.434   V((1, 0)) = 0.200   V((1, 1)) = 0.229   V((1, 2)) = 0.259   V((1, 3)) = 0.294   V((1, 4)) = 0.347   V((1, 5)) = 0.390   V((1, 6)) = 0.439   V((1, 7)) = 0.490   V((2, 0)) = 0.188   V((2, 1)) = 0.210   V((2, 2)) = 0.227   V((2, 3)) = 0.000   V((2, 4)) = 0.371   V((2, 5)) = 0.417   V((2, 6)) = 0.494   V((2, 7)) = 0.553   V((3, 0)) = 0.208   V((3, 1)) = 0.237   V((3, 2)) = 0.269   V((3, 3)) = 0.307   V((3, 4)) = 0.379   V((3, 5)) = 0.000   V((3, 6)) = 0.555   V((3, 7)) = 0.625   V((4, 0)) = 0.186   V((4, 1)) = 0.210   V((4, 2)) = 0.227   V((4, 3)) = 0.000   V((4, 4)) = 0.451   V((4, 5)) = 0.509   V((4, 6)) = 0.597   V((4, 7)) = 0.706   V((5, 0)) = 0.156   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.404   V((5, 4)) = 0.479   V((5, 5)) = 0.567   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.153   V((6, 1)) = 0.000   V((6, 2)) = 0.286   V((6, 3)) = 0.340   V((6, 4)) = 0.000   V((6, 5)) = 0.673   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.180   V((7, 1)) = 0.204   V((7, 2)) = 0.241   V((7, 3)) = 0.000   V((7, 4)) = 0.705   V((7, 5)) = 0.831   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter   19   |   diff: 0.00125   |   V((0, 0)) = 0.196   V((0, 1)) = 0.222   V((0, 2)) = 0.249   V((0, 3)) = 0.280   V((0, 4)) = 0.313   V((0, 5)) = 0.350   V((0, 6)) = 0.391   V((0, 7)) = 0.434   V((1, 0)) = 0.202   V((1, 1)) = 0.229   V((1, 2)) = 0.259   V((1, 3)) = 0.294   V((1, 4)) = 0.347   V((1, 5)) = 0.390   V((1, 6)) = 0.439   V((1, 7)) = 0.490   V((2, 0)) = 0.189   V((2, 1)) = 0.211   V((2, 2)) = 0.227   V((2, 3)) = 0.000   V((2, 4)) = 0.371   V((2, 5)) = 0.417   V((2, 6)) = 0.494   V((2, 7)) = 0.553   V((3, 0)) = 0.209   V((3, 1)) = 0.237   V((3, 2)) = 0.269   V((3, 3)) = 0.307   V((3, 4)) = 0.379   V((3, 5)) = 0.000   V((3, 6)) = 0.555   V((3, 7)) = 0.625   V((4, 0)) = 0.187   V((4, 1)) = 0.210   V((4, 2)) = 0.227   V((4, 3)) = 0.000   V((4, 4)) = 0.451   V((4, 5)) = 0.509   V((4, 6)) = 0.597   V((4, 7)) = 0.706   V((5, 0)) = 0.158   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.404   V((5, 4)) = 0.479   V((5, 5)) = 0.567   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.153   V((6, 1)) = 0.000   V((6, 2)) = 0.286   V((6, 3)) = 0.340   V((6, 4)) = 0.000   V((6, 5)) = 0.673   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.180   V((7, 1)) = 0.204   V((7, 2)) = 0.241   V((7, 3)) = 0.000   V((7, 4)) = 0.705   V((7, 5)) = 0.831   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter   20   |   diff: 0.00042   |   V((0, 0)) = 0.197   V((0, 1)) = 0.222   V((0, 2)) = 0.249   V((0, 3)) = 0.280   V((0, 4)) = 0.313   V((0, 5)) = 0.350   V((0, 6)) = 0.391   V((0, 7)) = 0.434   V((1, 0)) = 0.203   V((1, 1)) = 0.229   V((1, 2)) = 0.259   V((1, 3)) = 0.294   V((1, 4)) = 0.347   V((1, 5)) = 0.390   V((1, 6)) = 0.439   V((1, 7)) = 0.490   V((2, 0)) = 0.189   V((2, 1)) = 0.211   V((2, 2)) = 0.228   V((2, 3)) = 0.000   V((2, 4)) = 0.371   V((2, 5)) = 0.417   V((2, 6)) = 0.494   V((2, 7)) = 0.553   V((3, 0)) = 0.209   V((3, 1)) = 0.237   V((3, 2)) = 0.269   V((3, 3)) = 0.307   V((3, 4)) = 0.379   V((3, 5)) = 0.000   V((3, 6)) = 0.555   V((3, 7)) = 0.625   V((4, 0)) = 0.187   V((4, 1)) = 0.211   V((4, 2)) = 0.228   V((4, 3)) = 0.000   V((4, 4)) = 0.451   V((4, 5)) = 0.509   V((4, 6)) = 0.597   V((4, 7)) = 0.706   V((5, 0)) = 0.158   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.404   V((5, 4)) = 0.479   V((5, 5)) = 0.567   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.153   V((6, 1)) = 0.000   V((6, 2)) = 0.286   V((6, 3)) = 0.340   V((6, 4)) = 0.000   V((6, 5)) = 0.673   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.180   V((7, 1)) = 0.204   V((7, 2)) = 0.241   V((7, 3)) = 0.000   V((7, 4)) = 0.705   V((7, 5)) = 0.831   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter   21   |   diff: 0.00019   |   V((0, 0)) = 0.198   V((0, 1)) = 0.222   V((0, 2)) = 0.249   V((0, 3)) = 0.280   V((0, 4)) = 0.313   V((0, 5)) = 0.350   V((0, 6)) = 0.391   V((0, 7)) = 0.434   V((1, 0)) = 0.203   V((1, 1)) = 0.229   V((1, 2)) = 0.259   V((1, 3)) = 0.294   V((1, 4)) = 0.347   V((1, 5)) = 0.390   V((1, 6)) = 0.439   V((1, 7)) = 0.490   V((2, 0)) = 0.189   V((2, 1)) = 0.211   V((2, 2)) = 0.228   V((2, 3)) = 0.000   V((2, 4)) = 0.371   V((2, 5)) = 0.417   V((2, 6)) = 0.494   V((2, 7)) = 0.553   V((3, 0)) = 0.209   V((3, 1)) = 0.237   V((3, 2)) = 0.269   V((3, 3)) = 0.307   V((3, 4)) = 0.379   V((3, 5)) = 0.000   V((3, 6)) = 0.555   V((3, 7)) = 0.625   V((4, 0)) = 0.187   V((4, 1)) = 0.211   V((4, 2)) = 0.228   V((4, 3)) = 0.000   V((4, 4)) = 0.451   V((4, 5)) = 0.509   V((4, 6)) = 0.597   V((4, 7)) = 0.706   V((5, 0)) = 0.159   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.404   V((5, 4)) = 0.479   V((5, 5)) = 0.567   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.153   V((6, 1)) = 0.000   V((6, 2)) = 0.286   V((6, 3)) = 0.340   V((6, 4)) = 0.000   V((6, 5)) = 0.673   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.181   V((7, 1)) = 0.204   V((7, 2)) = 0.241   V((7, 3)) = 0.000   V((7, 4)) = 0.705   V((7, 5)) = 0.831   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter   22   |   diff: 0.00006   |   V((0, 0)) = 0.198   V((0, 1)) = 0.222   V((0, 2)) = 0.249   V((0, 3)) = 0.280   V((0, 4)) = 0.313   V((0, 5)) = 0.350   V((0, 6)) = 0.391   V((0, 7)) = 0.434   V((1, 0)) = 0.203   V((1, 1)) = 0.230   V((1, 2)) = 0.259   V((1, 3)) = 0.294   V((1, 4)) = 0.347   V((1, 5)) = 0.390   V((1, 6)) = 0.439   V((1, 7)) = 0.490   V((2, 0)) = 0.189   V((2, 1)) = 0.211   V((2, 2)) = 0.228   V((2, 3)) = 0.000   V((2, 4)) = 0.371   V((2, 5)) = 0.417   V((2, 6)) = 0.494   V((2, 7)) = 0.553   V((3, 0)) = 0.209   V((3, 1)) = 0.237   V((3, 2)) = 0.269   V((3, 3)) = 0.307   V((3, 4)) = 0.379   V((3, 5)) = 0.000   V((3, 6)) = 0.555   V((3, 7)) = 0.625   V((4, 0)) = 0.187   V((4, 1)) = 0.211   V((4, 2)) = 0.228   V((4, 3)) = 0.000   V((4, 4)) = 0.451   V((4, 5)) = 0.509   V((4, 6)) = 0.597   V((4, 7)) = 0.706   V((5, 0)) = 0.159   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.404   V((5, 4)) = 0.479   V((5, 5)) = 0.567   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.153   V((6, 1)) = 0.000   V((6, 2)) = 0.286   V((6, 3)) = 0.340   V((6, 4)) = 0.000   V((6, 5)) = 0.673   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.181   V((7, 1)) = 0.204   V((7, 2)) = 0.241   V((7, 3)) = 0.000   V((7, 4)) = 0.705   V((7, 5)) = 0.831   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter   23   |   diff: 0.00003   |   V((0, 0)) = 0.198   V((0, 1)) = 0.222   V((0, 2)) = 0.249   V((0, 3)) = 0.280   V((0, 4)) = 0.313   V((0, 5)) = 0.350   V((0, 6)) = 0.391   V((0, 7)) = 0.434   V((1, 0)) = 0.203   V((1, 1)) = 0.230   V((1, 2)) = 0.259   V((1, 3)) = 0.294   V((1, 4)) = 0.347   V((1, 5)) = 0.390   V((1, 6)) = 0.439   V((1, 7)) = 0.490   V((2, 0)) = 0.189   V((2, 1)) = 0.211   V((2, 2)) = 0.228   V((2, 3)) = 0.000   V((2, 4)) = 0.371   V((2, 5)) = 0.417   V((2, 6)) = 0.494   V((2, 7)) = 0.553   V((3, 0)) = 0.209   V((3, 1)) = 0.237   V((3, 2)) = 0.269   V((3, 3)) = 0.307   V((3, 4)) = 0.379   V((3, 5)) = 0.000   V((3, 6)) = 0.555   V((3, 7)) = 0.625   V((4, 0)) = 0.187   V((4, 1)) = 0.211   V((4, 2)) = 0.228   V((4, 3)) = 0.000   V((4, 4)) = 0.451   V((4, 5)) = 0.509   V((4, 6)) = 0.597   V((4, 7)) = 0.706   V((5, 0)) = 0.159   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.404   V((5, 4)) = 0.479   V((5, 5)) = 0.567   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.153   V((6, 1)) = 0.000   V((6, 2)) = 0.286   V((6, 3)) = 0.340   V((6, 4)) = 0.000   V((6, 5)) = 0.673   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.181   V((7, 1)) = 0.204   V((7, 2)) = 0.241   V((7, 3)) = 0.000   V((7, 4)) = 0.705   V((7, 5)) = 0.831   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter   24   |   diff: 0.00001   |   V((0, 0)) = 0.198   V((0, 1)) = 0.222   V((0, 2)) = 0.249   V((0, 3)) = 0.280   V((0, 4)) = 0.313   V((0, 5)) = 0.350   V((0, 6)) = 0.391   V((0, 7)) = 0.434   V((1, 0)) = 0.203   V((1, 1)) = 0.230   V((1, 2)) = 0.259   V((1, 3)) = 0.294   V((1, 4)) = 0.347   V((1, 5)) = 0.390   V((1, 6)) = 0.439   V((1, 7)) = 0.490   V((2, 0)) = 0.189   V((2, 1)) = 0.211   V((2, 2)) = 0.228   V((2, 3)) = 0.000   V((2, 4)) = 0.371   V((2, 5)) = 0.417   V((2, 6)) = 0.494   V((2, 7)) = 0.553   V((3, 0)) = 0.209   V((3, 1)) = 0.237   V((3, 2)) = 0.269   V((3, 3)) = 0.307   V((3, 4)) = 0.379   V((3, 5)) = 0.000   V((3, 6)) = 0.555   V((3, 7)) = 0.625   V((4, 0)) = 0.187   V((4, 1)) = 0.211   V((4, 2)) = 0.228   V((4, 3)) = 0.000   V((4, 4)) = 0.451   V((4, 5)) = 0.509   V((4, 6)) = 0.597   V((4, 7)) = 0.706   V((5, 0)) = 0.159   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.404   V((5, 4)) = 0.479   V((5, 5)) = 0.567   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.153   V((6, 1)) = 0.000   V((6, 2)) = 0.286   V((6, 3)) = 0.340   V((6, 4)) = 0.000   V((6, 5)) = 0.673   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.181   V((7, 1)) = 0.204   V((7, 2)) = 0.241   V((7, 3)) = 0.000   V((7, 4)) = 0.705   V((7, 5)) = 0.831   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter   25   |   diff: 0.00000   |   V((0, 0)) = 0.198   V((0, 1)) = 0.222   V((0, 2)) = 0.249   V((0, 3)) = 0.280   V((0, 4)) = 0.313   V((0, 5)) = 0.350   V((0, 6)) = 0.391   V((0, 7)) = 0.434   V((1, 0)) = 0.203   V((1, 1)) = 0.230   V((1, 2)) = 0.259   V((1, 3)) = 0.294   V((1, 4)) = 0.347   V((1, 5)) = 0.390   V((1, 6)) = 0.439   V((1, 7)) = 0.490   V((2, 0)) = 0.189   V((2, 1)) = 0.211   V((2, 2)) = 0.228   V((2, 3)) = 0.000   V((2, 4)) = 0.371   V((2, 5)) = 0.417   V((2, 6)) = 0.494   V((2, 7)) = 0.553   V((3, 0)) = 0.209   V((3, 1)) = 0.237   V((3, 2)) = 0.269   V((3, 3)) = 0.307   V((3, 4)) = 0.379   V((3, 5)) = 0.000   V((3, 6)) = 0.555   V((3, 7)) = 0.625   V((4, 0)) = 0.187   V((4, 1)) = 0.211   V((4, 2)) = 0.228   V((4, 3)) = 0.000   V((4, 4)) = 0.451   V((4, 5)) = 0.509   V((4, 6)) = 0.597   V((4, 7)) = 0.706   V((5, 0)) = 0.159   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.404   V((5, 4)) = 0.479   V((5, 5)) = 0.567   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.153   V((6, 1)) = 0.000   V((6, 2)) = 0.286   V((6, 3)) = 0.340   V((6, 4)) = 0.000   V((6, 5)) = 0.673   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.181   V((7, 1)) = 0.204   V((7, 2)) = 0.241   V((7, 3)) = 0.000   V((7, 4)) = 0.705   V((7, 5)) = 0.831   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# average reward:  0.887

# %%
print("PI large FrozenLake")
mdp = FrozenLakeEnv(map_name='8x8', slip_chance=0.1)
state_values, policy =  policy_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    rewards = []
    for t in range(100):
        s, r, done, _ = mdp.step(policy[s])
        rewards.append(r)
        if done:
            break
    total_rewards.append(np.sum(rewards))

print("average reward: ", np.mean(total_rewards))
# Out:
# PI large FrozenLake
# iter    0   |   diff: 0.94241   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((0, 4)) = 0.000   V((0, 5)) = 0.000   V((0, 6)) = 0.000   V((0, 7)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((1, 4)) = 0.000   V((1, 5)) = 0.000   V((1, 6)) = 0.000   V((1, 7)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((2, 4)) = 0.000   V((2, 5)) = 0.000   V((2, 6)) = 0.000   V((2, 7)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 0.000   V((3, 3)) = 0.000   V((3, 4)) = 0.000   V((3, 5)) = 0.000   V((3, 6)) = 0.000   V((3, 7)) = 0.000   V((4, 0)) = 0.000   V((4, 1)) = 0.000   V((4, 2)) = 0.000   V((4, 3)) = 0.000   V((4, 4)) = 0.000   V((4, 5)) = 0.000   V((4, 6)) = 0.000   V((4, 7)) = 0.000   V((5, 0)) = 0.000   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.000   V((5, 4)) = 0.000   V((5, 5)) = 0.000   V((5, 6)) = 0.000   V((5, 7)) = 0.000   V((6, 0)) = 0.000   V((6, 1)) = 0.000   V((6, 2)) = 0.000   V((6, 3)) = 0.000   V((6, 4)) = 0.000   V((6, 5)) = 0.000   V((6, 6)) = 0.000   V((6, 7)) = 0.000   V((7, 0)) = 0.000   V((7, 1)) = 0.000   V((7, 2)) = 0.000   V((7, 3)) = 0.000   V((7, 4)) = 0.000   V((7, 5)) = 0.000   V((7, 6)) = 0.000   V((7, 7)) = 0.000
# iter    1   |   diff: 0.79932   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((0, 4)) = 0.000   V((0, 5)) = 0.000   V((0, 6)) = 0.000   V((0, 7)) = 0.000   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((1, 4)) = 0.000   V((1, 5)) = 0.000   V((1, 6)) = 0.000   V((1, 7)) = 0.000   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((2, 4)) = 0.000   V((2, 5)) = -0.000   V((2, 6)) = -0.000   V((2, 7)) = 0.000   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 0.000   V((3, 3)) = 0.000   V((3, 4)) = 0.000   V((3, 5)) = 0.000   V((3, 6)) = -0.000   V((3, 7)) = 0.000   V((4, 0)) = 0.000   V((4, 1)) = 0.000   V((4, 2)) = 0.000   V((4, 3)) = 0.000   V((4, 4)) = 0.000   V((4, 5)) = 0.000   V((4, 6)) = 0.000   V((4, 7)) = 0.002   V((5, 0)) = 0.000   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.000   V((5, 4)) = 0.000   V((5, 5)) = 0.000   V((5, 6)) = 0.000   V((5, 7)) = 0.042   V((6, 0)) = 0.000   V((6, 1)) = 0.000   V((6, 2)) = 0.000   V((6, 3)) = 0.000   V((6, 4)) = 0.000   V((6, 5)) = 0.000   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.000   V((7, 1)) = 0.000   V((7, 2)) = 0.000   V((7, 3)) = 0.000   V((7, 4)) = 0.000   V((7, 5)) = 0.000   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter    2   |   diff: 0.67311   |   V((0, 0)) = 0.000   V((0, 1)) = 0.000   V((0, 2)) = 0.000   V((0, 3)) = 0.000   V((0, 4)) = 0.001   V((0, 5)) = 0.019   V((0, 6)) = 0.389   V((0, 7)) = 0.434   V((1, 0)) = 0.000   V((1, 1)) = 0.000   V((1, 2)) = 0.000   V((1, 3)) = 0.000   V((1, 4)) = 0.000   V((1, 5)) = 0.002   V((1, 6)) = 0.436   V((1, 7)) = 0.490   V((2, 0)) = 0.000   V((2, 1)) = 0.000   V((2, 2)) = 0.000   V((2, 3)) = 0.000   V((2, 4)) = 0.001   V((2, 5)) = 0.024   V((2, 6)) = 0.493   V((2, 7)) = 0.553   V((3, 0)) = 0.000   V((3, 1)) = 0.000   V((3, 2)) = 0.000   V((3, 3)) = 0.000   V((3, 4)) = 0.000   V((3, 5)) = 0.000   V((3, 6)) = 0.555   V((3, 7)) = 0.625   V((4, 0)) = 0.000   V((4, 1)) = 0.000   V((4, 2)) = 0.000   V((4, 3)) = 0.000   V((4, 4)) = 0.000   V((4, 5)) = 0.000   V((4, 6)) = 0.597   V((4, 7)) = 0.706   V((5, 0)) = 0.000   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.000   V((5, 4)) = 0.000   V((5, 5)) = 0.000   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.000   V((6, 1)) = 0.000   V((6, 2)) = 0.000   V((6, 3)) = 0.000   V((6, 4)) = 0.000   V((6, 5)) = 0.000   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.000   V((7, 1)) = 0.000   V((7, 2)) = 0.000   V((7, 3)) = 0.000   V((7, 4)) = 0.678   V((7, 5)) = 0.799   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter    3   |   diff: 0.31578   |   V((0, 0)) = 0.197   V((0, 1)) = 0.221   V((0, 2)) = 0.248   V((0, 3)) = 0.278   V((0, 4)) = 0.311   V((0, 5)) = 0.348   V((0, 6)) = 0.389   V((0, 7)) = 0.434   V((1, 0)) = 0.201   V((1, 1)) = 0.227   V((1, 2)) = 0.257   V((1, 3)) = 0.292   V((1, 4)) = 0.345   V((1, 5)) = 0.388   V((1, 6)) = 0.436   V((1, 7)) = 0.490   V((2, 0)) = 0.173   V((2, 1)) = 0.194   V((2, 2)) = 0.217   V((2, 3)) = 0.000   V((2, 4)) = 0.367   V((2, 5)) = 0.417   V((2, 6)) = 0.493   V((2, 7)) = 0.553   V((3, 0)) = 0.153   V((3, 1)) = 0.173   V((3, 2)) = 0.195   V((3, 3)) = 0.250   V((3, 4)) = 0.308   V((3, 5)) = 0.000   V((3, 6)) = 0.555   V((3, 7)) = 0.625   V((4, 0)) = 0.126   V((4, 1)) = 0.141   V((4, 2)) = 0.164   V((4, 3)) = 0.000   V((4, 4)) = 0.272   V((4, 5)) = 0.495   V((4, 6)) = 0.597   V((4, 7)) = 0.706   V((5, 0)) = 0.107   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.203   V((5, 4)) = 0.241   V((5, 5)) = 0.247   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.090   V((6, 1)) = 0.000   V((6, 2)) = 0.144   V((6, 3)) = 0.171   V((6, 4)) = 0.000   V((6, 5)) = 0.673   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.082   V((7, 1)) = 0.103   V((7, 2)) = 0.121   V((7, 3)) = 0.000   V((7, 4)) = 0.705   V((7, 5)) = 0.831   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter    4   |   diff: 0.07920   |   V((0, 0)) = 0.198   V((0, 1)) = 0.222   V((0, 2)) = 0.249   V((0, 3)) = 0.280   V((0, 4)) = 0.313   V((0, 5)) = 0.350   V((0, 6)) = 0.391   V((0, 7)) = 0.434   V((1, 0)) = 0.202   V((1, 1)) = 0.229   V((1, 2)) = 0.259   V((1, 3)) = 0.294   V((1, 4)) = 0.347   V((1, 5)) = 0.390   V((1, 6)) = 0.439   V((1, 7)) = 0.490   V((2, 0)) = 0.181   V((2, 1)) = 0.203   V((2, 2)) = 0.219   V((2, 3)) = 0.000   V((2, 4)) = 0.368   V((2, 5)) = 0.417   V((2, 6)) = 0.494   V((2, 7)) = 0.553   V((3, 0)) = 0.163   V((3, 1)) = 0.196   V((3, 2)) = 0.221   V((3, 3)) = 0.250   V((3, 4)) = 0.309   V((3, 5)) = 0.000   V((3, 6)) = 0.555   V((3, 7)) = 0.625   V((4, 0)) = 0.146   V((4, 1)) = 0.174   V((4, 2)) = 0.187   V((4, 3)) = 0.000   V((4, 4)) = 0.444   V((4, 5)) = 0.509   V((4, 6)) = 0.597   V((4, 7)) = 0.706   V((5, 0)) = 0.124   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.337   V((5, 4)) = 0.400   V((5, 5)) = 0.563   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.105   V((6, 1)) = 0.000   V((6, 2)) = 0.239   V((6, 3)) = 0.284   V((6, 4)) = 0.000   V((6, 5)) = 0.673   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.150   V((7, 1)) = 0.171   V((7, 2)) = 0.201   V((7, 3)) = 0.000   V((7, 4)) = 0.705   V((7, 5)) = 0.831   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter    5   |   diff: 0.00861   |   V((0, 0)) = 0.198   V((0, 1)) = 0.222   V((0, 2)) = 0.249   V((0, 3)) = 0.280   V((0, 4)) = 0.313   V((0, 5)) = 0.350   V((0, 6)) = 0.391   V((0, 7)) = 0.434   V((1, 0)) = 0.202   V((1, 1)) = 0.229   V((1, 2)) = 0.259   V((1, 3)) = 0.294   V((1, 4)) = 0.347   V((1, 5)) = 0.390   V((1, 6)) = 0.439   V((1, 7)) = 0.490   V((2, 0)) = 0.181   V((2, 1)) = 0.203   V((2, 2)) = 0.219   V((2, 3)) = 0.000   V((2, 4)) = 0.371   V((2, 5)) = 0.417   V((2, 6)) = 0.494   V((2, 7)) = 0.553   V((3, 0)) = 0.208   V((3, 1)) = 0.236   V((3, 2)) = 0.269   V((3, 3)) = 0.307   V((3, 4)) = 0.379   V((3, 5)) = 0.000   V((3, 6)) = 0.555   V((3, 7)) = 0.625   V((4, 0)) = 0.187   V((4, 1)) = 0.210   V((4, 2)) = 0.227   V((4, 3)) = 0.000   V((4, 4)) = 0.451   V((4, 5)) = 0.509   V((4, 6)) = 0.597   V((4, 7)) = 0.706   V((5, 0)) = 0.158   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.404   V((5, 4)) = 0.479   V((5, 5)) = 0.567   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.153   V((6, 1)) = 0.000   V((6, 2)) = 0.286   V((6, 3)) = 0.340   V((6, 4)) = 0.000   V((6, 5)) = 0.673   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.181   V((7, 1)) = 0.204   V((7, 2)) = 0.241   V((7, 3)) = 0.000   V((7, 4)) = 0.705   V((7, 5)) = 0.831   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter    6   |   diff: 0.00221   |   V((0, 0)) = 0.198   V((0, 1)) = 0.222   V((0, 2)) = 0.249   V((0, 3)) = 0.280   V((0, 4)) = 0.313   V((0, 5)) = 0.350   V((0, 6)) = 0.391   V((0, 7)) = 0.434   V((1, 0)) = 0.203   V((1, 1)) = 0.230   V((1, 2)) = 0.259   V((1, 3)) = 0.294   V((1, 4)) = 0.347   V((1, 5)) = 0.390   V((1, 6)) = 0.439   V((1, 7)) = 0.490   V((2, 0)) = 0.187   V((2, 1)) = 0.211   V((2, 2)) = 0.228   V((2, 3)) = 0.000   V((2, 4)) = 0.371   V((2, 5)) = 0.417   V((2, 6)) = 0.494   V((2, 7)) = 0.553   V((3, 0)) = 0.209   V((3, 1)) = 0.237   V((3, 2)) = 0.269   V((3, 3)) = 0.307   V((3, 4)) = 0.379   V((3, 5)) = 0.000   V((3, 6)) = 0.555   V((3, 7)) = 0.625   V((4, 0)) = 0.187   V((4, 1)) = 0.211   V((4, 2)) = 0.228   V((4, 3)) = 0.000   V((4, 4)) = 0.451   V((4, 5)) = 0.509   V((4, 6)) = 0.597   V((4, 7)) = 0.706   V((5, 0)) = 0.159   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.404   V((5, 4)) = 0.479   V((5, 5)) = 0.567   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.153   V((6, 1)) = 0.000   V((6, 2)) = 0.286   V((6, 3)) = 0.340   V((6, 4)) = 0.000   V((6, 5)) = 0.673   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.181   V((7, 1)) = 0.204   V((7, 2)) = 0.241   V((7, 3)) = 0.000   V((7, 4)) = 0.705   V((7, 5)) = 0.831   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# iter    7   |   diff: 0.00000   |   V((0, 0)) = 0.198   V((0, 1)) = 0.222   V((0, 2)) = 0.249   V((0, 3)) = 0.280   V((0, 4)) = 0.313   V((0, 5)) = 0.350   V((0, 6)) = 0.391   V((0, 7)) = 0.434   V((1, 0)) = 0.203   V((1, 1)) = 0.230   V((1, 2)) = 0.259   V((1, 3)) = 0.294   V((1, 4)) = 0.347   V((1, 5)) = 0.390   V((1, 6)) = 0.439   V((1, 7)) = 0.490   V((2, 0)) = 0.189   V((2, 1)) = 0.211   V((2, 2)) = 0.228   V((2, 3)) = 0.000   V((2, 4)) = 0.371   V((2, 5)) = 0.417   V((2, 6)) = 0.494   V((2, 7)) = 0.553   V((3, 0)) = 0.209   V((3, 1)) = 0.237   V((3, 2)) = 0.269   V((3, 3)) = 0.307   V((3, 4)) = 0.379   V((3, 5)) = 0.000   V((3, 6)) = 0.555   V((3, 7)) = 0.625   V((4, 0)) = 0.187   V((4, 1)) = 0.211   V((4, 2)) = 0.228   V((4, 3)) = 0.000   V((4, 4)) = 0.451   V((4, 5)) = 0.509   V((4, 6)) = 0.597   V((4, 7)) = 0.706   V((5, 0)) = 0.159   V((5, 1)) = 0.000   V((5, 2)) = 0.000   V((5, 3)) = 0.404   V((5, 4)) = 0.479   V((5, 5)) = 0.567   V((5, 6)) = 0.000   V((5, 7)) = 0.799   V((6, 0)) = 0.153   V((6, 1)) = 0.000   V((6, 2)) = 0.286   V((6, 3)) = 0.340   V((6, 4)) = 0.000   V((6, 5)) = 0.673   V((6, 6)) = 0.000   V((6, 7)) = 0.942   V((7, 0)) = 0.181   V((7, 1)) = 0.204   V((7, 2)) = 0.241   V((7, 3)) = 0.000   V((7, 4)) = 0.705   V((7, 5)) = 0.831   V((7, 6)) = 0.942   V((7, 7)) = 0.000
# average reward:  0.889

# %% [markdown]
# ## Policy iteration convergence (3 pts)
#
# **Note:** Assume that $\mathcal{S}, \mathcal{A}$ are finite.
#
# We can define another Bellman operator:
#
# $$(T_{\pi}V)(s) = \mathbb{E}_{r, s'|s, a = \pi(s)}\left[r + \gamma V(s')\right]$$
#
# And rewrite policy iteration algorithm in operator form:
#
#
# ---
#
# Initialize $\pi_0$
#
# **for** $k = 0,1,2,...$ **do**
#
# &nbsp;&nbsp;&nbsp;&nbsp; Solve $V_k = T_{\pi_k}V_k$
#
# &nbsp;&nbsp;&nbsp;&nbsp; Select $\pi_{k+1}$ s.t. $T_{\pi_{k+1}}V_k = TV_k$
#
# **end for**
#
# ---
#
# To prove convergence of the algorithm we need to prove two properties: contraction an monotonicity.
#
# #### Monotonicity (0.5 pts)
#
# For all $V, U$ if $V(s) \le U(s)$   $\forall s \in \mathcal{S}$ then $(T_\pi V)(s) \le (T_\pi U)(s)$   $\forall s \in  \mathcal{S}$
#
# Proof.
# $$(T_{\pi}V)(s) - (T_{\pi}U)(s)  = \mathbb{E}_{r, s'|s, a = \pi(s)}\left[r + \gamma V(s')\right] - \mathbb{E}_{r, s'|s, a = \pi(s)}\left[r + \gamma U(s')\right] = r(s, \pi(s)) + \gamma\mathbb{E}_{s'|s, a = \pi(s)}\left[V(s')\right] - r(s, \pi(s)) - \gamma\mathbb{E}_{s'|s, a = \pi(s)}\left[U(s')\right]= \gamma \mathbb{E}_{s'|s, a = \pi(s)}\left[V(s') - U(s')\right] \le 0$$
#
# #### Contraction (1 pts)
#
# $$
# ||T_\pi V - T_\pi U||_{\infty} \le \gamma ||V - U||_{\infty}
# $$
#
# For all $V, U$
#
# Proof.
# Для любого $s$
# $$(T_{\pi}V)(s) - (T_{\pi}U)(s)  = \mathbb{E}_{r, s'|s, a = \pi(s)}\left[r + \gamma V(s')\right] - \mathbb{E}_{r, s'|s, a = \pi(s)}\left[r + \gamma U(s')\right] = r(s, \pi(s)) + \gamma\mathbb{E}_{s'|s, a = \pi(s)}\left[V(s')\right] - r(s, \pi(s)) - \gamma\mathbb{E}_{s'|s, a = \pi(s)}\left[U(s')\right]= \gamma \mathbb{E}_{s'|s, a = \pi(s)}\left[V(s') - U(s')\right] \le  \gamma \mathbb{E}_{s'|s, a = \pi(s)}\left[|V(s') - U(s')|\right] \le \gamma \max_{s'}|V(s') - U(s')| = \gamma ||V - U||_{\infty}$$
#
# Так как данное соотношение выполняется для любого $s$, то
# $||T_\pi V - T_\pi U||_{\infty} \le \gamma ||V - U||_{\infty}$
#
#
# #### Convergence (1.5 pts)
#
# Prove that there exists iteration $k_0$ such that $\pi_k = \pi^*$ for all $k \ge k_0$
#
# Proof.
# Аналогично value iteration
# $$
# \left\|V_{k}-V^*\right\|_{\infty} = \left\|T_{\pi_{k}} V_k - T_{\pi_{k}} V^*\right\|_{\infty} \leq \gamma\left\|V_{k - 1}-V^*\right\|_{\infty} \leq \gamma^k\left\|V_0-V^*\right\|_{\infty}
# $$
#
# $$\lim _{k \rightarrow \infty} V_k=V^*$$
#
# Тогда из определения предела
# $$
# \forall \epsilon>0 \exists k_0(\epsilon): \forall k \geq k_0(\epsilon)$$
# $$\left\|V_k-V^*\right\|_{\infty} \leq \epsilon$$
#
# Пусть $\epsilon = \min_{\pi}\left\|V_{\pi}-V^*\right\|_{\infty}$ / 2 (множество политик конечно по условию)
# Тогда $$ \exists k_0  \forall k \geq k_0: \left\|V_k-V^*\right\|_{\infty} \leq \epsilon$$, то есть $$\left\|V_k-V^*\right\|_{\infty} = 0$$
# $V_k = V^*$ и $\pi_k=\pi^*$
